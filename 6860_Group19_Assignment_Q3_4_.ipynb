# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import re
from functools import reduce
from scipy.stats import pearsonr
import matplotlib.ticker as mticker

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from collections import defaultdict
import geopandas as gpd

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
reviews = pd.read_csv('edu_services_google_reviews.csv')
edu1 = pd.read_csv('Education-services-au-export.csv')

# %% [markdown]
# # Import Dataset & Cleaning
# **AEDC**
#
# The Australian Early Development Census (AEDC) dataset contains information about the developmental status of children in different Local Government Areas (LGAs) across several domains (such as physical health, social competence, emotional maturity, language and cognitive skills, and communication skills).
# - identify which LGAs have the highest proportions of developmentally vulnerable children (DV1, DV2).
# - analyze disparities in child development outcomes across regions and domains.
# - compare these outcomes with socio-economic and geographic factors.
#
# **Google Reviews**
#
# For education-related service providers (such as preschools and childcare centers).
# - perform sentiment analysis and understand public perception of education services.
# - assess the quality of services from the perspective of parents and the community.
# - explore the relationship between review sentiment/ratings and AEDC outcomes.
#
# **LGA Time-Series**
#
# Time-series data for various AEDC domains and subdomains at the LGA level, often including multiple years of data.
# What it’s used for:
# - analyze trends and changes in child development outcomes over time.
# - compare progress or decline in different LGAs and domains.
# - support longitudinal analysis for policy evaluation.
#
# **Education Services**
#
# Detailed information about education service providers, including their names, locations, types, quality ratings (such as NQS), and accessibility features.
# - map the distribution and accessibility of education services across LGAs.
# - analyze the alignment between service quality/availability and AEDC outcomes.
# - investigate whether areas with more or higher-quality services have better child development outcomes.

# %% [markdown]
# ## LGA (lga)

# %%
sheet = pd.ExcelFile('LGA 2009-21.xlsx').sheet_names
print(sheet)
sheet
# Out:
# ['Contents', 'LGA Health', 'LGA Social', 'LGA Emotional', 'LGA Language', 'LGA Communication', 'LGA One or more', 'LGA Two or more', 'LGA On track all', 'LGA Health 1 Subdomain', 'LGA Health 2 Subdomain', 'LGA Health 3 Subdomain']
# ['Contents',
#  'LGA Health',
#  'LGA Social',
#  'LGA Emotional',
#  'LGA Language',
#  'LGA Communication',
#  'LGA One or more',
#  'LGA Two or more',
#  'LGA On track all',
#  'LGA Health 1 Subdomain',
#  'LGA Health 2 Subdomain',
#  'LGA Health 3 Subdomain']

# %% [markdown]
# Developmentally vulnerable refers to the total number of children in each LGA and each year who participated in the assessment for a given domain and received a valid score.
#
# We only retain the percentage of developmentally vulnerable children, as this allows for direct comparison of vulnerability levels across different LGAs, years, and domains, without being affected by the total number of children in each area.
#
# The number (n) is only suitable for examining absolute scale, but does not reflect the relative severity.

# %%
lga_xlsx = pd.ExcelFile('LGA 2009-21.xlsx')
sheet_names = [ 'LGA Health',
                'LGA Social',
                'LGA Emotional',
                'LGA Language',
                'LGA Communication',
                'LGA One or more',
                'LGA Two or more']

states_to_remove = [
    "New South Wales", "Victoria", "Queensland",
    "Western Australia", "South Australia",
    "Tasmania", "Australian Capital Territory", "Northern Territory"
]

lga_dict = {}
for name in sheet_names:
    lga_dict[name] = pd.read_excel(lga_xlsx, sheet_name=name, skiprows=4)
    lga_dict[name] = lga_dict[name].drop(lga_dict[name].columns[0], axis=1) # delete the empty column

    lga_percent = lga_dict[name].iloc[:, [0, 1, -9, -7, -5, -3, -1]] # filter developmentally vulnerable
    lga_percent.columns = ['Code', 'Name', '2009', '2012', '2015', '2018', '2021']  # rename columns

    lga_percent = lga_percent[~lga_percent['Code'].astype(str).isin(states_to_remove)] # remove the state rows
    lga_percent = lga_percent.rename(columns={'Name': 'Suburb'}) # rename suburb col
    lga_percent = lga_percent.dropna()

    lga_dict[name] = lga_percent.reset_index(drop=True)

# %%
for sheet in sheet_names:
    print(f"Sheet: {sheet}")
    print(lga_dict[sheet].head())
    print('-' * 100)
# Out:
# Sheet: LGA Health
#     Code             Suburb       2009       2012       2015       2018  \
# 0  10050             Albury  10.221465   10.25641   7.783418  12.460064
# 1  10180  Armidale Regional  11.079545  14.164306   8.064516  13.489736
# 2  10250            Ballina   8.297872   7.121662   4.608295   8.492569
# 3  10300          Balranald   6.451613   6.451613  12.121212   3.448276
# 4  10470  Bathurst Regional   9.766454  11.111111   8.949416  11.372549
#
#         2021
# 0  11.402157
# 1   12.37785
# 2   6.965174
# 3  33.333333
# 4  15.953307
# ----------------------------------------------------------------------------------------------------
# Sheet: LGA Social
#     Code             Suburb       2009       2012       2015       2018  \
# 0  10050             Albury  11.754685  12.820513  10.490694  15.335463
# 1  10180  Armidale Regional   9.943182  12.464589   6.774194   9.677419
# 2  10250            Ballina  11.914894   7.121662   8.064516   9.766454
# 3  10300          Balranald   6.451613   9.677419   9.090909          0
# 4  10470  Bathurst Regional  10.191083   7.392996   5.642023  11.764706
#
#         2021
# 0  12.326656
# 1  10.423453
# 2   6.965174
# 3  17.647059
# 4  16.731518
# ----------------------------------------------------------------------------------------------------
# Sheet: LGA Emotional
#     Code             Suburb      2009      2012      2015      2018       2021
# 0  10050             Albury   9.91453  7.692308  8.319185  9.455128   9.876543
# 1  10180  Armidale Regional  8.547009   9.68661  2.922078  7.038123   9.771987
# 2  10250            Ballina  9.850107  5.135952  6.682028  7.543103   8.706468
# 3  10300          Balranald  6.451613        10  9.090909  6.896552  17.647059
# 4  10470  Bathurst Regional  9.129512  4.678363  4.678363  8.823529   8.333333
# ----------------------------------------------------------------------------------------------------
# Sheet: LGA Language
#     Code             Suburb      2009      2012      2015      2018       2021
# 0  10050             Albury  5.451448  7.211538  4.230118      9.12   6.317411
# 1  10180  Armidale Regional  7.977208  7.648725   5.16129  7.624633   10.09772
# 2  10250            Ballina  6.823028  2.686567  3.456221  5.307856   6.716418
# 3  10300          Balranald  3.225806  3.225806  3.030303  6.896552  11.764706
# 4  10470  Bathurst Regional  5.944798  5.058366  2.918288  6.666667   6.420233
# ----------------------------------------------------------------------------------------------------
# Sheet: LGA Communication
#     Code             Suburb      2009       2012      2015       2018  \
# 0  10050             Albury  8.517888   9.775641  5.245347   9.904153
# 1  10180  Armidale Regional      12.5  17.280453  9.385113  12.316716
# 2  10250            Ballina  5.957447    6.52819  5.299539   5.944798
# 3  10300          Balranald  6.451613  12.903226  6.060606   3.448276
# 4  10470  Bathurst Regional  6.581741   5.447471  8.560311   9.607843
#
#         2021
# 0   9.707242
# 1  10.423453
# 2   6.218905
# 3  16.666667
# 4  12.256809
# ----------------------------------------------------------------------------------------------------
# Sheet: LGA One or more
#     Code             Suburb       2009       2012       2015       2018  \
# 0  10050             Albury  23.339012         25  20.203735  26.038339
# 1  10180  Armidale Regional  25.925926  31.818182  17.475728  24.633431
# 2  10250            Ballina    24.8394  16.969697  15.437788  18.064516
# 3  10300          Balranald  16.129032         30  12.121212  17.241379
# 4  10470  Bathurst Regional  23.142251  20.272904  16.374269  23.137255
#
#         2021
# 0  24.345146
# 1  27.687296
# 2  16.915423
# 3  47.058824
# 4  31.683168
# ----------------------------------------------------------------------------------------------------
# Sheet: LGA Two or more
#     Code             Suburb       2009       2012      2015       2018  \
# 0  10050             Albury  12.776831  12.179487   9.98308  15.015974
# 1  10180  Armidale Regional  14.814815   15.29745  8.064516  12.316716
# 2  10250            Ballina    10.8742   6.845238  8.064516  10.425532
# 3  10300          Balranald   9.677419  12.903226  9.090909   3.448276
# 4  10470  Bathurst Regional  11.677282   8.187135  7.198444  13.529412
#
#         2021
# 0  13.734568
# 1  13.680782
# 2   8.955224
# 3  29.411765
# 4  15.984405
# ----------------------------------------------------------------------------------------------------

# %%
domain_map = {
    'LGA Health': 'Health',
    'LGA Social': 'Social',
    'LGA Emotional': 'Emotional',
    'LGA Language': 'Language',
    'LGA Communication': 'Communication',
    'LGA One or more': 'DV1',
    'LGA Two or more': 'DV2'
}

for name in lga_dict:
    prefix = domain_map[name]
    lga_dict[name] = lga_dict[name].rename(
        columns={year: f"{prefix}_{year}" for year in ['2009', '2012', '2015', '2018', '2021']}
    )

dfs = list(lga_dict.values())
lga = reduce(lambda left, right: pd.merge(left, right, on=['Code', 'Suburb'], how='outer'), dfs)

# Separate column for year
lga = pd.melt(lga,id_vars=['Code', 'Suburb'],var_name='Domain_Year',value_name='Percentage') # Merge all data frames horizontally
lga[['Domain', 'Year']] = lga['Domain_Year'].str.split('_', expand=True) # Split Domain_Year into Domain and Year
lga = lga[['Code', 'Suburb', 'Domain', 'Year', 'Percentage']] # Select the columns we want to keep
lga = lga.rename(columns={'Year': 'LGA_Year'})
lga = lga.rename(columns={'Percentage': 'Domain_pct'})
lga = lga.rename(columns={'Code': 'lga_code'})

lga.sample(20)
# Out:
#       lga_code                         Suburb         Domain LGA_Year  \
# 2773     12160  Cootamundra-Gundagai Regional         Social     2009
# 11847    46970                    Roxby Downs  Communication     2012
# 16485    13010              Glen Innes Severn            DV2     2009
# 10169    41960               Franklin Harbour       Language     2018
# 16863    54410                   Kellerberrin            DV2     2009
# 4933     10180              Armidale Regional         Social     2021
# 11826    44060                         Marion  Communication     2012
# 11449    59250                         Wiluna  Communication     2009
# 7261     21110                     Boroondara      Emotional     2018
# 7513     52100                       Corrigin      Emotional     2018
# 16121    32600                        Croydon            DV1     2021
# 18138    14000                        Hornsby            DV2     2018
# 18829    26700                     Wangaratta            DV2     2021
# 18193    17420                The Hills Shire            DV2     2018
# 2134     59310                 Wongan-Ballidu         Health     2018
# 6560     71150     Darwin Waterfront Precinct      Emotional     2012
# 4389     10500                  Bayside (NSW)         Social     2018
# 14919    18350                  Wingecarribee            DV1     2015
# 3299     10850                        Blayney         Social     2012
# 18350    36150                        Quilpie            DV2     2018
#
#       Domain_pct
# 2773    8.064516
# 11847          8
# 16485   9.401709
# 10169          *
# 16863  11.764706
# 4933   10.423453
# 11826   8.074534
# 11449          *
# 7261    4.915049
# 7513           0
# 16121          *
# 18138   5.711319
# 18829  12.538226
# 18193   5.942623
# 2134    5.263158
# 6560           *
# 4389    9.797724
# 14919  21.212121
# 3299    6.382979
# 18350          *

# %% [markdown]
# The LGA dataset contains missing or suppressed values (e.g., , ≥90, blanks) due to insufficient valid scores or confidentiality requirements. In this analysis, we retain only numeric values. Suppressed values displayed as are assumed to represent a relatively low rate and are imputed as 1%. For interval values (e.g., ≥90), only the numeric part is retained. All other missing values are dropped.

# %%
def extract_number(val):
    if isinstance(val, str):
        if val.strip() == '*':
            return 1.0  # Impute suppressed values as 1%
        match = re.search(r'\d+\.?\d*', val)
        if match:
            return float(match.group())  # Keep only the numeric part for intervals
        else:
            return None
    return val

lga['Domain_pct'] = lga['Domain_pct'].apply(extract_number)
lga['Domain_pct'] = pd.to_numeric(lga['Domain_pct'], errors='coerce').round(4)
lga = lga.dropna(subset=['Domain_pct'])

print(lga.sample(20))
# Out:
#       lga_code              Suburb         Domain LGA_Year  Domain_pct
# 16451    10850             Blayney            DV2     2009     13.8889
# 1536     55600               Moora         Health     2015     12.9032
# 2882     21610               Casey         Social     2009     10.2667
# 6799     32260     Cassowary Coast      Emotional     2015     10.2500
# 15256    57140            Pingelly            DV1     2015      1.0000
# 396      52590          Dandaragan         Health     2009      5.4054
# 3739     56460            Narrogin         Social     2012      9.5238
# 15357    10950               Bogan            DV1     2018     14.6341
# 1248     22490       Golden Plains         Health     2015      3.9157
# 11535    11720            Cessnock  Communication     2012      8.8315
# 11849    47290     Southern Mallee  Communication     2012     14.2857
# 9767     56460            Narrogin       Language     2015     10.6667
# 18671    12750         Eurobodalla            DV2     2021     15.2174
# 5454     65210              Tasman         Social     2021      1.0000
# 5591     17620  Upper Hunter Shire      Emotional     2009      3.7037
# 5691     30370              Banana      Emotional     2009      9.7345
# 6329     41330         Coober Pedy      Emotional     2012      8.0000
# 14988    26350         Stonnington            DV1     2015     11.9149
# 15790    56090           Mundaring            DV1     2018     19.5431
# 5205     36660      Southern Downs         Social     2021     13.1707

# %%
lga['Suburb'] = lga['Suburb'].str.upper().str.replace(r'\s*\(.*?\)', '', regex=True)
lga['Suburb'] = lga['Suburb'].str.replace(r'[^A-Z0-9 ]', '', regex=True)
lga['Suburb'] = lga['Suburb'].str.replace(r'\s+', ' ', regex=True)
lga['Suburb'] = lga['Suburb'].str.strip()
lga = lga.dropna(subset=['Suburb'])
state = ['NSW', 'VIC', 'QLD', 'SA', 'WA', 'TAS', 'NT', 'ACT']
pattern = r'\s*[\-\.]?\s*(' + '|'.join(state) + r')\.?$'
lga['Suburb'] = lga['Suburb'].str.replace(pattern, '', regex=True).str.strip()

lga['Suburb'].unique().tolist()
# Out:
# ['ALBURY',
#  'ARMIDALE REGIONAL',
#  'BALLINA',
#  'BALRANALD',
#  'BATHURST REGIONAL',
#  'BAYSIDE',
#  'BEGA VALLEY',
#  'BELLINGEN',
#  'BERRIGAN',
#  'BLACKTOWN',
#  'BLAND',
#  'BLAYNEY',
#  'BLUE MOUNTAINS',
#  'BOGAN',
#  'BOURKE',
#  'BREWARRINA',
#  'BROKEN HILL',
#  'BURWOOD',
#  'BYRON',
#  'CABONNE',
#  'CAMDEN',
#  'CAMPBELLTOWN',
#  'CANADA BAY',
#  'CANTERBURYBANKSTOWN',
#  'CARRATHOOL',
#  'CENTRAL COAST',
#  'CENTRAL DARLING',
#  'CESSNOCK',
#  'CLARENCE VALLEY',
#  'COBAR',
#  'COFFS HARBOUR',
#  'COOLAMON',
#  'COONAMBLE',
#  'COOTAMUNDRAGUNDAGAI REGIONAL',
#  'COWRA',
#  'CUMBERLAND',
#  'DUBBO REGIONAL',
#  'DUNGOG',
#  'EDWARD RIVER',
#  'EUROBODALLA',
#  'FAIRFIELD',
#  'FEDERATION',
#  'FORBES',
#  'GEORGES RIVER',
#  'GILGANDRA',
#  'GLEN INNES SEVERN',
#  'GOULBURN MULWAREE',
#  'GREATER HUME SHIRE',
#  'GRIFFITH',
#  'GUNNEDAH',
#  'GWYDIR',
#  'HAWKESBURY',
#  'HAY',
#  'HILLTOPS',
#  'HORNSBY',
#  'HUNTERS HILL',
#  'INNER WEST',
#  'INVERELL',
#  'JUNEE',
#  'KEMPSEY',
#  'KIAMA',
#  'KURINGGAI',
#  'KYOGLE',
#  'LACHLAN',
#  'LAKE MACQUARIE',
#  'LANE COVE',
#  'LEETON',
#  'LISMORE',
#  'LITHGOW',
#  'LIVERPOOL',
#  'LIVERPOOL PLAINS',
#  'LOCKHART',
#  'MAITLAND',
#  'MIDCOAST',
#  'MIDWESTERN REGIONAL',
#  'MOREE PLAINS',
#  'MOSMAN',
#  'MURRAY RIVER',
#  'MURRUMBIDGEE',
#  'MUSWELLBROOK',
#  'NAMBUCCA VALLEY',
#  'NARRABRI',
#  'NARRANDERA',
#  'NARROMINE',
#  'NEWCASTLE',
#  'NORTH SYDNEY',
#  'NORTHERN BEACHES',
#  'OBERON',
#  'ORANGE',
#  'PARKES',
#  'PARRAMATTA',
#  'PENRITH',
#  'PORT MACQUARIEHASTINGS',
#  'PORT STEPHENS',
#  'QUEANBEYANPALERANG REGIONAL',
#  'RANDWICK',
#  'RICHMOND VALLEY',
#  'RYDE',
#  'SHELLHARBOUR',
#  'SHOALHAVEN',
#  'SINGLETON',
#  'SNOWY MONARO REGIONAL',
#  'SNOWY VALLEYS',
#  'STRATHFIELD',
#  'SUTHERLAND SHIRE',
#  'SYDNEY',
#  'TAMWORTH REGIONAL',
#  'TEMORA',
#  'TENTERFIELD',
#  'THE HILLS SHIRE',
#  'TWEED',
#  'UPPER HUNTER SHIRE',
#  'UPPER LACHLAN SHIRE',
#  'URALLA',
#  'WAGGA WAGGA',
#  'WALCHA',
#  'WALGETT',
#  'WARREN',
#  'WARRUMBUNGLE SHIRE',
#  'WAVERLEY',
#  'WEDDIN',
#  'WENTWORTH',
#  'WILLOUGHBY',
#  'WINGECARRIBEE',
#  'WOLLONDILLY',
#  'WOLLONGONG',
#  'WOOLLAHRA',
#  'YASS VALLEY',
#  'UNINCORPORATED',
#  'ALPINE',
#  'ARARAT',
#  'BALLARAT',
#  'BANYULE',
#  'BASS COAST',
#  'BAW BAW',
#  'BENALLA',
#  'BOROONDARA',
#  'BRIMBANK',
#  'BULOKE',
#  'CAMPASPE',
#  'CARDINIA',
#  'CASEY',
#  'CENTRAL GOLDFIELDS',
#  'COLAC OTWAY',
#  'CORANGAMITE',
#  'DAREBIN',
#  'EAST GIPPSLAND',
#  'FRANKSTON',
#  'GANNAWARRA',
#  'GLEN EIRA',
#  'GLENELG',
#  'GOLDEN PLAINS',
#  'GREATER BENDIGO',
#  'GREATER DANDENONG',
#  'GREATER GEELONG',
#  'GREATER SHEPPARTON',
#  'HEPBURN',
#  'HINDMARSH',
#  'HOBSONS BAY',
#  'HORSHAM',
#  'HUME',
#  'INDIGO',
#  'KINGSTON',
#  'KNOX',
#  'LATROBE',
#  'LODDON',
#  'MACEDON RANGES',
#  'MANNINGHAM',
#  'MANSFIELD',
#  'MARIBYRNONG',
#  'MAROONDAH',
#  'MELBOURNE',
#  'MELTON',
#  'MILDURA',
#  'MITCHELL',
#  'MOIRA',
#  'MONASH',
#  'MOONEE VALLEY',
#  'MOORABOOL',
#  'MORELAND',
#  'MORNINGTON PENINSULA',
#  'MOUNT ALEXANDER',
#  'MOYNE',
#  'MURRINDINDI',
#  'NILLUMBIK',
#  'NORTHERN GRAMPIANS',
#  'PORT PHILLIP',
#  'PYRENEES',
#  'QUEENSCLIFFE',
#  'SOUTH GIPPSLAND',
#  'SOUTHERN GRAMPIANS',
#  'STONNINGTON',
#  'STRATHBOGIE',
#  'SURF COAST',
#  'SWAN HILL',
#  'TOWONG',
#  'WANGARATTA',
#  'WARRNAMBOOL',
#  'WELLINGTON',
#  'WEST WIMMERA',
#  'WHITEHORSE',
#  'WHITTLESEA',
#  'WODONGA',
#  'WYNDHAM',
#  'YARRA',
#  'YARRA RANGES',
#  'YARRIAMBIACK',
#  'AURUKUN',
#  'BALONNE',
#  'BANANA',
#  'BARCALDINE',
#  'BARCOO',
#  'BLACKALL TAMBO',
#  'BOULIA',
#  'BRISBANE',
#  'BULLOO',
#  'BUNDABERG',
#  'BURDEKIN',
#  'BURKE',
#  'CAIRNS',
#  'CARPENTARIA',
#  'CASSOWARY COAST',
#  'CENTRAL HIGHLANDS',
#  'CHARTERS TOWERS',
#  'CHERBOURG',
#  'CLONCURRY',
#  'COOK',
#  'CROYDON',
#  'DIAMANTINA',
#  'DOOMADGEE',
#  'DOUGLAS',
#  'ETHERIDGE',
#  'FLINDERS',
#  'FRASER COAST',
#  'GLADSTONE',
#  'GOLD COAST',
#  'GOONDIWINDI',
#  'GYMPIE',
#  'HINCHINBROOK',
#  'HOPE VALE',
#  'IPSWICH',
#  'ISAAC',
#  'KOWANYAMA',
#  'LIVINGSTONE',
#  'LOCKHART RIVER',
#  'LOCKYER VALLEY',
#  'LOGAN',
#  'LONGREACH',
#  'MACKAY',
#  'MCKINLAY',
#  'MAPOON',
#  'MARANOA',
#  'MAREEBA',
#  'MORETON BAY',
#  'MORNINGTON',
#  'MOUNT I',
#  'MURWEH',
#  'NAPRANUM',
#  'NOO',
#  'NORTH BURNETT',
#  'NORTHERN PENINSULA AREA',
#  'PALM ISLAND',
#  'PAROO',
#  'PORMPURAAW',
#  'QUILPIE',
#  'REDLAND',
#  'RICHMOND',
#  'ROCKHAMPTON',
#  'SCENIC RIM',
#  'SOMERSET',
#  'SOUTH BURNETT',
#  'SOUTHERN DOWNS',
#  'SUNSHINE COAST',
#  'TABLELANDS',
#  'TOOWOOMBA',
#  'TORRES',
#  'TORRES STRAIT ISLAND',
#  'TOWNSVILLE',
#  'WEIPA',
#  'WESTERN DOWNS',
#  'WHITSUNDAY',
#  'WINTON',
#  'WOORABINDA',
#  'WUJAL WUJAL',
#  'YARRABAH',
#  'ADELAIDE',
#  'ADELAIDE HILLS',
#  'ADELAIDE PLAINS',
#  'ALEXANDRINA',
#  'ANANGU PITJANTJATJARA YUNKUNYT',
#  'BAROS',
#  'BARUNGA WEST',
#  'BERRI BARMERA',
#  'BURNSIDE',
#  'CEDUNA',
#  'CHARLES STURT',
#  'CLARE AND GILBERT VALLEYS',
#  'CLEVE',
#  'COOBER PEDY',
#  'COPPER COAST',
#  'ELLISTON',
#  'FLINDERS RANGES',
#  'FRANKLIN HARBOUR',
#  'GAWLER',
#  'GOYDER',
#  'GRA',
#  'HOLDFAST BAY',
#  'KANGAROO ISLAND',
#  'KAROONDA EAST MURRAY',
#  'KIMBA',
#  'LIGHT',
#  'LOWER EYRE PENINSULA',
#  'LOXTON WAIKERIE',
#  'MARALINGA TJARUTJA',
#  'MARION',
#  'MID MURRAY',
#  'MITCHAM',
#  'MOUNT BARKER',
#  'MOUNT GAMBIER',
#  'MOUNT REMARKABLE',
#  'MURRAY BRIDGE',
#  'NARACOORTE LUCINDALE',
#  'NORTHERN AREAS',
#  'NORWOOD PAYNEHAM AND ST PETERS',
#  'ONKAPARINGA',
#  'ORROROO CARRIETON',
#  'PETERBOROUGH',
#  'PLAYFORD',
#  'PORT ADELAIDE ENFIELD',
#  'PORT AUGUSTA',
#  'PORT LINCOLN',
#  'PORT PIRIE',
#  'PROSPECT',
#  'RENMARK PARINGA',
#  'ROBE',
#  'ROXBY DOWNS',
#  'SALISBURY',
#  'SOUTHERN MALLEE',
#  'STREAKY BAY',
#  'TATIARA',
#  'TEA TREE GULLY',
#  'COORONG',
#  'TUMBY BAY',
#  'UNLEY',
#  'VICTOR HARBOR',
#  'WAKEFIELD',
#  'WALKERVILLE',
#  'WATTLE RANGE',
#  'WEST TORRENS',
#  'WHYALLA',
#  'WUDINNA',
#  'YANKALILLA',
#  'YORKE PENINSULA',
#  'ALBANY',
#  'ARMADALE',
#  'ASHBURTON',
#  'AUGUSTA MARGARET RIVER',
#  'BASSENDEAN',
#  'BAYSWATER',
#  'BELMO',
#  'BEVERLEY',
#  'BODDINGTON',
#  'BOYUP BROOK',
#  'BRIDGETOWNGREENBUSHES',
#  'BROOKTON',
#  'BROOME',
#  'BROOMEHILLTAMBELLUP',
#  'BRUCE ROCK',
#  'BUNBURY',
#  'BUSSELTON',
#  'CAMBRIDGE',
#  'CANNING',
#  'CAPEL',
#  'CARNAMAH',
#  'CARNARVON',
#  'CHAPMAN VALLEY',
#  'CHITTERING',
#  'CHRISTMAS ISLAND',
#  'CLAREMO',
#  'COCKBURN',
#  'COCOS ISLANDS',
#  'COLLIE',
#  'COOLGARDIE',
#  'COOROW',
#  'CORRIGIN',
#  'COTTESLOE',
#  'CRANBROOK',
#  'CUBALLING',
#  'CUE',
#  'CUNDERDIN',
#  'DALWALLINU',
#  'DANDARAGAN',
#  'DARDANUP',
#  'DENMARK',
#  'DERBYWEST KIMBERLEY',
#  'DONNYBROOKBALINGUP',
#  'DOWERIN',
#  'DUMBLEYUNG',
#  'DUNDAS',
#  'EAST FREMANTLE',
#  'EAST PILBARA',
#  'ESPERANCE',
#  'EXMOUTH',
#  'FREMANTLE',
#  'GINGIN',
#  'GNOWANGERUP',
#  'GOOMALLING',
#  'GOSNELLS',
#  'GREATER GERALDTON',
#  'HALLS CREEK',
#  'HARVEY',
#  'IRWIN',
#  'JERRAMUNGUP',
#  'JOONDALUP',
#  'KALAMUNDA',
#  'KALGOORLIEBOULDER',
#  'KARRATHA',
#  'KATANNING',
#  'KELLERBERRIN',
#  'KE',
#  'KOJONUP',
#  'KONDININ',
#  'KOORDA',
#  'KULIN',
#  'KWINANA',
#  'LAKE GRACE',
#  'LAVERTON',
#  'LEONORA',
#  'MANDURAH',
#  'MANJIMUP',
#  'MEEKATHARRA',
#  'MELVILLE',
#  'MENZIES',
#  'MERREDIN',
#  'MINGENEW',
#  'MOORA',
#  'MORA',
#  'MOSMAN PARK',
#  'MOUNT MAGNET',
#  'MOUNT MARSHALL',
#  'MUKINBUDIN',
#  'MUNDARING',
#  'MURCHISON',
#  'MURRAY',
#  'NANNUP',
#  'NAREMBEEN',
#  'NARROGIN',
#  'NEDLANDS',
#  'NGAANYATJARRAKU',
#  'NORTHAM',
#  'NORTHAMPTON',
#  'NUNGARIN',
#  'PEPPERMINT GROVE',
#  'PERENJORI',
#  'PERTH',
#  'PINGELLY',
#  'PLANTAGENET',
#  'PORT HEDLAND',
#  'QUAIRADING',
#  'RAVENSTHORPE',
#  'ROCKINGHAM',
#  'SANDSTONE',
#  'SERPENTINEJARRAHDALE',
#  'SHARK BAY',
#  'SOUTH PERTH',
#  'STIRLING',
#  'SUBIACO',
#  'SWAN',
#  'TAMMIN',
#  'THREE SPRINGS',
#  'TOODYAY',
#  'TRAYNING',
#  'UPPER GASCOYNE',
#  'VICTORIA PARK',
#  'VICTORIA PLAINS',
#  'VINCE',
#  'WAGIN',
#  'WANDERING',
#  'WANNEROO',
#  'WAROONA',
#  'WEST ARTHUR',
#  'WESTONIA',
#  'WICKEPIN',
#  'WILLIAMS',
#  'WILUNA',
#  'WONGANBALLIDU',
#  'WOODANILLING',
#  'WYALKATCHEM',
#  'WYNDHAMEAST KIMBERLEY',
#  'YALGOO',
#  'YILGARN',
#  'YORK',
#  'BREAK ODAY',
#  'BRIGHTON',
#  'BURNIE',
#  'CIRCULAR HEAD',
#  'CLARENCE',
#  'DERWENT VALLEY',
#  'DEVONPORT',
#  'DORSET',
#  'GEORGE TOWN',
#  'GLAMORGANSPRING BAY',
#  'GLENORCHY',
#  'HOBART',
#  'HUON VALLEY',
#  'KENTISH',
#  'KING ISLAND',
#  'KINGBOROUGH',
#  'LAUNCESTON',
#  'MEANDER VALLEY',
#  'NORTHERN MIDLANDS',
#  'SORELL',
#  'SOUTHERN MIDLANDS',
#  'TASMAN',
#  'WARATAHWYNYARD',
#  'WEST COAST',
#  'WEST TAMAR',
#  'ALICE SPRINGS',
#  'BARKLY',
#  'BELYUEN',
#  'CENTRAL DESERT',
#  'COOMALIE',
#  'DARWIN',
#  'DARWIN WATERFRONT PRECINCT',
#  'EAST ARNHEM',
#  'KATHERINE',
#  'LITCHFIELD',
#  'MACDONNELL',
#  'PALMERSTON',
#  'ROPER GULF',
#  'TIWI ISLANDS',
#  'VICTORIA DALY',
#  'WAGAIT',
#  'WEST ARNHEM',
#  'WEST DALY',
#  'UNINCORP OTHER TERRITORIES',
#  'NORFOLK ISLAND']

# %%
lga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19180 entries, 0 to 19179
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lga_code    19180 non-null  object
#  1   Suburb      19180 non-null  object
#  2   Domain      19180 non-null  object
#  3   LGA_Year    19180 non-null  object
#  4   Domain_pct  19180 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 749.3+ KB

# %% [markdown]
# ## AEDC (aedc)

# %%
sheet1_names = ['Table_2', 'Table_3']
adec_dict = {}
for name1 in sheet1_names:
    df = pd.read_excel('42400DO002_2023.xlsx', sheet_name=name1, skiprows=57, nrows=1)
    df.columns = ['Category', 'NSW', 'VIC', 'QLD', 'SA', 'WA', 'TAS', 'NT', 'ACT','AU']
    adec_dict[name1] = df

for sheet in sheet1_names:
    print(f"Sheet: {sheet}")
    print(adec_dict[sheet].head())
# Out:
# Sheet: Table_2
#                                          Category     NSW    VIC    QLD  \
# 0  Total children enrolled in a preschool program  104887  97129  63125
#
#       SA     WA   TAS    NT   ACT      AU
# 0  20051  34522  7616  3161  6819  337305
# Sheet: Table_3
#                                        Category     NSW    VIC    QLD     SA  \
# 0  Total children attending a preschool program  103962  91507  61851  19668
#
#       WA   TAS    NT   ACT      AU
# 0  32944  7519  2789  6696  326933

# %%
enrollment = adec_dict['Table_2']
attendance = adec_dict['Table_3']

enroll_total_row = enrollment[enrollment['Category'].str.contains('Total children enrolled', case=False, na=False)].iloc[0]
attend_total_row = attendance[attendance['Category'].str.contains('Total children attending', case=False, na=False)].iloc[0]

states = ['NSW', 'VIC', 'QLD', 'SA', 'WA', 'TAS', 'NT', 'ACT']

enrollment_au = float(enroll_total_row['AU'])
attendance_au = float(attend_total_row['AU'])

aedc = pd.DataFrame({'State': states})
aedc['Enrollment'] = [float(enroll_total_row[state]) for state in states]
aedc['Attendance'] = [float(attend_total_row[state]) for state in states]
aedc['Enrollment_pct'] = (aedc['Enrollment'] / enrollment_au * 100).round(4)
aedc['Attendance_pct'] = (aedc['Attendance'] / attendance_au * 100).round(4)

aedc = aedc[['State', 'Enrollment_pct', 'Attendance_pct']]
print(aedc)
# Out:
#   State  Enrollment_pct  Attendance_pct
# 0   NSW         31.0956         31.7992
# 1   VIC         28.7956         27.9895
# 2   QLD         18.7145         18.9186
# 3    SA          5.9445          6.0159
# 4    WA         10.2347         10.0767
# 5   TAS          2.2579          2.2999
# 6    NT          0.9371          0.8531
# 7   ACT          2.0216          2.0481

# %% [markdown]
# ## Education Service Provides (edu)

# %% [markdown]
# | Keep | Remove (examples) |
# |----------------------------------|--------------------------------------|
# | ServiceApprovalNumber | Phone, Fax, Conditions on Approval |
# | Provider Approval Number | All timetable/session columns |
# | ServiceName, ProviderLegalName | PreviousQualityArea* columns |
# | ServiceType, ServiceAddress | Other, Temporarily Closed |
# | Suburb, State, Postcode | |
# | NumberOfApprovedPlaces | |
# | QualityArea1-7Rating, OverallRating, RatingsIssued | |
# | Long Day Care, Preschool/Kindergarten, Outside school Hours Care | |

# %%
edu1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17663 entries, 0 to 17662
# Data columns (total 97 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   ServiceApprovalNumber                             17663 non-null  object
#  1   Provider Approval Number                          17663 non-null  object
#  2   ServiceName                                       17663 non-null  object
#  3   ProviderLegalName                                 17556 non-null  object
#  4   ServiceType                                       17663 non-null  object
#  5   ServiceAddress                                    17653 non-null  object
#  6   Suburb                                            17653 non-null  object
#  7   State                                             17653 non-null  object
#  8   Postcode                                          17653 non-null  float64
#  9   Phone                                             16918 non-null  object
#  10  Fax                                               5242 non-null   object
#  11  Conditions on Approval                            6247 non-null   object
#  12  NumberOfApprovedPlaces                            17246 non-null  float64
#  13  ServiceApprovalGrantedDate                        17662 non-null  object
#  14  QualityArea1Rating                                16336 non-null  object
#  15  QualityArea2Rating                                16336 non-null  object
#  16  QualityArea3Rating                                16336 non-null  object
#  17  QualityArea4Rating                                16336 non-null  object
#  18  QualityArea5Rating                                16336 non-null  object
#  19  QualityArea6Rating                                16336 non-null  object
#  20  QualityArea7Rating                                16336 non-null  object
#  21  OverallRating                                     16336 non-null  object
#  22  RatingsIssued                                     16336 non-null  object
#  23  PreviousQualityArea1Rating                        13144 non-null  object
#  24  PreviousQualityArea2Rating                        13144 non-null  object
#  25  PreviousQualityArea3Rating                        13144 non-null  object
#  26  PreviousQualityArea4Rating                        13144 non-null  object
#  27  PreviousQualityArea5Rating                        13144 non-null  object
#  28  PreviousQualityArea6Rating                        13144 non-null  object
#  29  PreviousQualityArea7Rating                        13144 non-null  object
#  30  PreviousOverallRating                             13144 non-null  object
#  31  PreviousRatingsIssued                             13144 non-null  object
#  32  Last Service Approval Transfer Date               5352 non-null   object
#  33  Long Day Care                                     17663 non-null  object
#  34  Preschool/Kindergarten - Part of a School         17663 non-null  object
#  35  Preschool/Kindergarten - Stand alone              17663 non-null  object
#  36  Outside school Hours Care - After School          17663 non-null  object
#  37  Outside school Hours Care - Before School         17663 non-null  object
#  38  Outside school Hours Care - Vacation Care         17663 non-null  object
#  39  Other                                             17663 non-null  object
#  40  Annual Monday Start Time                          10685 non-null  object
#  41  Annual Monday End Time                            10685 non-null  object
#  42  Annual Tuesday Start Time                         10731 non-null  object
#  43  Annual Tuesday End Time                           10731 non-null  object
#  44  Annual Wednesday Start Time                       10733 non-null  object
#  45  Annual Wednesday End Time                         10733 non-null  object
#  46  Annual Thursday Start Time                        10722 non-null  object
#  47  Annual Thursday End Time                          10722 non-null  object
#  48  Annual Friday Start Time                          10655 non-null  object
#  49  Annual Friday End Time                            10655 non-null  object
#  50  Annual Saturday Start Time                        224 non-null    object
#  51  Annual Saturday End Time                          223 non-null    object
#  52  Annual Sunday Start Time                          129 non-null    object
#  53  Annual Sunday End Time                            128 non-null    object
#  54  School Terms Only Session 1 Monday Start Time     7268 non-null   object
#  55  School Terms Only Session 1 Monday End Time       7268 non-null   object
#  56  School Terms Only Session 1 Tuesday Start Time    7448 non-null   object
#  57  School Terms Only Session 1 Tuesday End Time      7448 non-null   object
#  58  School Terms Only Session1 Wednesday Start Time   7351 non-null   object
#  59  School Terms Only Session1 Wednesday End Time     7351 non-null   object
#  60  School Terms Only Session1 Thursday Start Time    7249 non-null   object
#  61  School Terms Only Session1 Thursday End Time      7249 non-null   object
#  62  School Terms Only Session 1 Friday Start Time     6825 non-null   object
#  63  School Terms Only Session 1 Friday End Time       6825 non-null   object
#  64  School Terms Only Session 1 Saturday Start Time   39 non-null     object
#  65  School Terms Only Session 1 Saturday End Time     39 non-null     object
#  66  School Terms Only Session1 Sunday Start Time      24 non-null     object
#  67  School Terms Only Session 1 Sunday End Time       24 non-null     object
#  68  School Terms Only Session 2 Monday Start Time     5534 non-null   object
#  69  School Terms Only Session 2 Monday End Time       5534 non-null   object
#  70  School Terms Only Session 2 Tuesday Start Time    5638 non-null   object
#  71  School Terms Only Session 2 Tuesday End Time      5638 non-null   object
#  72  School Terms Only Session 2 Wednesday Start Time  5651 non-null   object
#  73  School Terms Only Session 2 Wednesday End Time    5651 non-null   object
#  74  School Terms Only Session 2 Thursday Start Time   5674 non-null   object
#  75  School Terms Only Session2 Thursday End Time      5674 non-null   object
#  76  School Terms Only Session 2 Friday Start Time     5549 non-null   object
#  77  School Terms Only Session 2 Friday End Time       5549 non-null   object
#  78  School Terms Only Session 2 Saturday Start Time   19 non-null     object
#  79  School Terms Only Session 2 Saturday End Time     19 non-null     object
#  80  School Terms Only Session 2 Sunday Start Time     14 non-null     object
#  81  School Terms Only Session 2 Sunday End Time       14 non-null     object
#  82  Holiday Care Monday Start Time                    4796 non-null   object
#  83  Holiday Care Monday End Time                      4795 non-null   object
#  84  Holiday Care Tuesday Start Time                   4806 non-null   object
#  85  Holiday Care Tuesday End Time                     4805 non-null   object
#  86  Holiday Care Wednesday Start Time                 4804 non-null   object
#  87  Holiday Care Wednesday End Time                   4803 non-null   object
#  88  Holiday Care Thursday Start Time                  4802 non-null   object
#  89  Holiday Care Thursday End Time                    4800 non-null   object
#  90  Holiday Care Friday Start Time                    4778 non-null   object
#  91  Holiday Care Friday End Time                      4777 non-null   object
#  92  Holiday Care Saturday Start Time                  89 non-null     object
#  93  Holiday Care Saturday End Time                    89 non-null     object
#  94  Holiday Care Sunday Start Time                    59 non-null     object
#  95  Holiday Care Sunday End Time                      59 non-null     object
#  96  Temporarily Closed                                17663 non-null  object
# dtypes: float64(2), object(95)
# memory usage: 13.1+ MB

# %%
edu = edu1[
    [
        'ServiceName',
        'ProviderLegalName',
        'ServiceType',
        'Suburb',
        'State',
        'Postcode',
        'NumberOfApprovedPlaces',
        'QualityArea1Rating',  # 1 - Educational program and practice
        'QualityArea2Rating',  # 2 - Children’s health and safety
        'QualityArea3Rating',  # 3 - Physical environment
        'QualityArea4Rating',  # 4 - Staffing arrangements
        'QualityArea5Rating',  # 5 - Relationships with children
        'QualityArea6Rating',  # 6 - Collaborative partnerships with families and communities
        'QualityArea7Rating',  # 7 - Governance and leadership
        'OverallRating',
        'RatingsIssued',
        'Long Day Care',
        'Preschool/Kindergarten - Part of a School',
        'Preschool/Kindergarten - Stand alone',
        'Outside school Hours Care - After School',
        'Outside school Hours Care - Before School',
        'Outside school Hours Care - Vacation Care'
    ]
]
edu.head()
# Out:
#                                          ServiceName  \
# 0    Community Kids Waterford Early Education Centre
# 1                  KIDVENTURE EARLY LEARNING EAGLEBY
# 2                 Community Kids - Broadbeach Waters
# 3  Little Scholars School of Early Learning Burle...
# 4                     Small World Child Care Centre
#
#                                    ProviderLegalName        ServiceType  \
# 0                               G8 Education Limited  Centre-Based Care
# 1  Table Mountain Trading Pty Ltd As The Trustee ...  Centre-Based Care
# 2                               G8 Education Limited  Centre-Based Care
# 3                         The Scholars Group Pty Ltd  Centre-Based Care
# 4  A. & K. Massouras Pty. Ltd. ATF The A Massoura...  Centre-Based Care
#
#               Suburb State  Postcode  NumberOfApprovedPlaces  \
# 0     WATERFORD WEST   QLD    4133.0                    60.0
# 1            EAGLEBY   QLD    4207.0                    74.0
# 2  BROADBEACH WATERS   QLD    4217.0                    75.0
# 3    BURLEIGH WATERS   QLD    4220.0                   106.0
# 4            CARRARA   QLD    4211.0                    92.0
#
#   QualityArea1Rating QualityArea2Rating QualityArea3Rating QualityArea4Rating  \
# 0        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
# 1        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
# 2        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
# 3        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
# 4        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
#
#     QualityArea5Rating QualityArea6Rating QualityArea7Rating  \
# 0          Meeting NQS        Meeting NQS        Meeting NQS
# 1  Working Towards NQS        Meeting NQS        Meeting NQS
# 2          Meeting NQS        Meeting NQS        Meeting NQS
# 3          Meeting NQS        Meeting NQS        Meeting NQS
# 4          Meeting NQS        Meeting NQS        Meeting NQS
#
#          OverallRating RatingsIssued Long Day Care  \
# 0          Meeting NQS      Sep 2023           Yes
# 1  Working Towards NQS      Apr 2023           Yes
# 2          Meeting NQS      Dec 2022           Yes
# 3          Meeting NQS      Oct 2019           Yes
# 4          Meeting NQS      Jul 2023           Yes
#
#   Preschool/Kindergarten - Part of a School  \
# 0                                        No
# 1                                        No
# 2                                        No
# 3                                        No
# 4                                        No
#
#   Preschool/Kindergarten - Stand alone  \
# 0                                  Yes
# 1                                  Yes
# 2                                  Yes
# 3                                   No
# 4                                   No
#
#   Outside school Hours Care - After School  \
# 0                                       No
# 1                                      Yes
# 2                                       No
# 3                                       No
# 4                                      Yes
#
#   Outside school Hours Care - Before School  \
# 0                                        No
# 1                                       Yes
# 2                                        No
# 3                                        No
# 4                                       Yes
#
#   Outside school Hours Care - Vacation Care
# 0                                        No
# 1                                       Yes
# 2                                        No
# 3                                        No
# 4                                       Yes

# %%
edu['Suburb'] = edu['Suburb'].str.upper()
edu['Suburb'] = edu['Suburb'].str.strip()
edu['Suburb'] = edu['Suburb'].str.replace(r'\s+', ' ', regex=True)
edu['Suburb'] = edu['Suburb'].str.replace(r'[^A-Z0-9 ]', '', regex=True)
edu['Suburb'].unique().tolist()
# Out:
# ['WATERFORD WEST',
#  'EAGLEBY',
#  'BROADBEACH WATERS',
#  'BURLEIGH WATERS',
#  'CARRARA',
#  'CURRUMBIN WATERS',
#  'ELANORA',
#  'HELENSVALE',
#  'MERMAID WATERS',
#  'MUDGEERABA',
#  'WORONGARY',
#  'NERANG',
#  'OXENFORD',
#  'ROBINA',
#  'BILOELA',
#  'MORANBAH',
#  'CLERMONT',
#  'BOWEN',
#  'ACACIA RIDGE',
#  'ALGESTER',
#  'ASHGROVE',
#  'ASPLEY',
#  'BOONDALL',
#  'BULIMBA',
#  'CARINDALE',
#  'CARINA',
#  'CLAYFIELD',
#  'COORPAROO',
#  'ENOGGERA',
#  'EVERTON PARK',
#  'FORTITUDE VALLEY',
#  'GRACEVILLE',
#  'HOLLAND PARK',
#  'INALA',
#  'INDOOROOPILLY',
#  'JINDALEE',
#  'HERSTON',
#  'KENMORE',
#  'MCDOWALL',
#  'MANLY',
#  'MANLY WEST',
#  'MANSFIELD',
#  'MITCHELTON',
#  'MOOROOKA',
#  'MORNINGSIDE',
#  'MOUNT GRAVATT',
#  'NATHAN',
#  'NEWMARKET',
#  'NORTHGATE',
#  'RED HILL',
#  'RIVERHILLS',
#  'RUNCORN',
#  'ST LUCIA',
#  'SANDGATE',
#  'SHERWOOD',
#  'SOUTH BRISBANE',
#  'SPRING HILL',
#  'STAFFORD',
#  'CALAMVALE',
#  'TARINGA',
#  'TARRAGINDI',
#  'EKIBIN',
#  'THE GAP',
#  'TINGALPA',
#  'TOOWONG',
#  'HILL END',
#  'WEST END',
#  'WILSTON',
#  'WINDSOR',
#  'WOOLLOONGABBA',
#  'WYNNUM',
#  'WYNNUM WEST',
#  'YERONGA',
#  'MIDDLEMOUNT',
#  'DYSART',
#  'BUNDABERG',
#  'AYR',
#  'CABOOLTURE',
#  'EARLVILLE',
#  'MOOROOBOOL',
#  'CAIRNS',
#  'EDMONTON',
#  'GOLDEN BEACH',
#  'CALOUNDRA',
#  'MINYAMA',
#  'KARUMBA',
#  'DALBY',
#  'PORT DOUGLAS',
#  'BLACKWATER',
#  'EMERALD',
#  'GATTON',
#  'GLADSTONE',
#  'MOLENDINAR',
#  'ASHMORE',
#  'BENOWA',
#  'BURLEIGH HEADS',
#  'LABRADOR',
#  'MIAMI',
#  'PALM BEACH',
#  'RUNAWAY BAY',
#  'COOMBABAH',
#  'SOUTHPORT',
#  'TUGUN',
#  'GOONDIWINDI',
#  'GYMPIE',
#  'HERVEY BAY',
#  'INGHAM',
#  'SADLIERS CROSSING',
#  'GOODNA',
#  'BOOVAL',
#  'BRASSALL',
#  'NORTH IPSWICH',
#  'MISSION BEACH',
#  'KINGAROY',
#  'YEPPOON',
#  'BROWNS PLAINS',
#  'DAISY HILL',
#  'BORONIA HEIGHTS',
#  'KINGSTON',
#  'LOGANHOLME',
#  'LOGANLEA',
#  'MARSDEN',
#  'ROCHEDALE SOUTH',
#  'SHAILER PARK',
#  'SLACKS CREEK',
#  'WOODRIDGE',
#  'SOUTH MACKAY',
#  'MACKAY',
#  'MAREEBA',
#  'MAROOCHYDORE',
#  'NAMBOUR',
#  'MOOLOOLABA',
#  'BUDERIM',
#  'WOOMBYE',
#  'MARYBOROUGH',
#  'MOUNT ISA',
#  'NOOSAVILLE',
#  'TEWANTIN',
#  'ALBANY CREEK',
#  'EVERTON HILLS',
#  'FERNY HILLS',
#  'KALLANGUR',
#  'PETRIE',
#  'NORTH MACKAY',
#  'ANDERGROVE',
#  'REDCLIFFE',
#  'KIPPARING',
#  'ALEXANDRA HILLS',
#  'BEENLEIGH',
#  'CAPALABA',
#  'ORMISTON',
#  'THORNLANDS',
#  'VICTORIA POINT',
#  'WELLINGTON POINT',
#  'ROCKHAMPTON',
#  'NORTH ROCKHAMPTON',
#  'KIRWAN',
#  'DEERAGUN',
#  'RASMUSSEN',
#  'TOOWOOMBA',
#  'NORTH WARD',
#  'CRANBROOK',
#  'CURRAJONG',
#  'TOWNSVILLE',
#  'GARBUTT',
#  'GULLIVER',
#  'ANNANDALE',
#  'PIMLICO',
#  'BELGIAN GARDENS',
#  'WARWICK',
#  'TIN CAN BAY',
#  'MEADOWBROOK',
#  'COOLUM BEACH',
#  'SALISBURY',
#  'CONDON',
#  'SMITHFIELD',
#  'CHERBOURG',
#  'CURRUMBIN',
#  'LOGAN VILLAGE',
#  'EDENS LANDING',
#  'STONES CORNER',
#  'PARKWOOD',
#  'VARSITY LAKES',
#  'LONGREACH',
#  'CLONCURRY',
#  'BELLBIRD PARK',
#  'GORDONVALE',
#  'MILTON',
#  'EAST BRISBANE',
#  'PARK RIDGE',
#  'BIRKDALE',
#  'STRATHPINE',
#  'NEW FARM',
#  'HIGHLAND PARK',
#  'FIG TREE POCKET',
#  'BRIBIE ISLAND',
#  'BRACKEN RIDGE',
#  'CLONTARF',
#  'NORTH TAMBORINE',
#  'KULUIN',
#  'MOUNTAIN CREEK',
#  'MOUNT COOLUM',
#  'JIMBOOMBA',
#  'UNDERWOOD',
#  'AEROGLEN',
#  'PARKHURST',
#  'PIALBA',
#  'BETHANIA',
#  'EIGHT MILE PLAINS',
#  'MERRIMAC',
#  'MANUNDA',
#  'BIGGERA WATERS',
#  'LANDSBOROUGH',
#  'BEERWAH',
#  'BRIGHTON',
#  'FERNVALE',
#  'OXLEY',
#  'SUNSHINE BEACH',
#  'DURACK',
#  'LAWNTON',
#  'KELVIN GROVE',
#  'THURSDAY ISLAND',
#  'TOOMBUL',
#  'FOREST LAKE',
#  'COOROY',
#  'ARUNDEL',
#  'MALENY',
#  'TULLY',
#  'KELSO',
#  'MOSSMAN',
#  'HEATLEY',
#  'BENTLEY PARK',
#  'GILSTON',
#  'LOGAN CENTRAL',
#  'CHERMSIDE WEST',
#  'WEST BURLEIGH',
#  'KEPERRA',
#  'BRAY PARK',
#  'KURABY',
#  'KARANA DOWNS',
#  'RACEVIEW',
#  'CANNONVALE',
#  'ROMA',
#  'PROSERPINE',
#  'CRESTMEAD',
#  'SPRINGWOOD',
#  'AUCHENFLOWER',
#  'COLLINGWOOD PARK',
#  'RIVERVIEW',
#  'TALLEBUDGERA',
#  'WARANA',
#  'PARADISE POINT',
#  'BURLEIGH WEST',
#  'HENDRA',
#  'HYDE PARK',
#  'WULGURU',
#  'WOOLOOWIN',
#  'STAFFORD HEIGHTS',
#  'MORAYFIELD',
#  'ROTHWELL',
#  'EDGE HILL',
#  'AITKENVALE',
#  'WHITE ROCK',
#  'JENSEN',
#  'WOREE',
#  'HAWTHORNE',
#  'COOPERS PLAINS',
#  'CAMP MOUNTAIN',
#  'EATONS HILL',
#  'BELMONT',
#  'REDBANK',
#  'SARINA',
#  'SPRINGFIELD',
#  'REDBANK PLAINS',
#  'AROONA',
#  'REEDY CREEK',
#  'CANNON HILL',
#  'KARALEE',
#  'TAIGUM',
#  'POMONA',
#  'FERNY GROVE',
#  'DAYBORO',
#  'DECEPTION BAY',
#  'HILLCREST',
#  'NORTH BUDERIM',
#  'CARBROOK',
#  'BEAUDESERT',
#  'WATERFORD',
#  'LOWOOD',
#  'KOONGAL',
#  'CHERMSIDE',
#  'WOODFORD',
#  'BUNDAMBA',
#  'TINANA',
#  'BONOGIN',
#  'TORQUAY',
#  'BUDDINA',
#  'NORMANTON',
#  'BELLMERE',
#  'YAMANTO',
#  'EUMUNDI',
#  'HIGHFIELDS',
#  'KEWARRA BEACH',
#  'NANANGO',
#  'EIMEO',
#  'CHARTERS TOWERS',
#  'TRINITY BEACH',
#  'NINGI',
#  'PIMPAMA',
#  'WESTCOURT',
#  'INNISFAIL',
#  'CANUNGRA',
#  'ROSEWOOD',
#  'MOUNT WARREN PARK',
#  'BOONAH',
#  'CURRIMUNDI',
#  'ROCHEDALE',
#  'TANNUM SANDS',
#  'WITHCOTT',
#  'REGENTS PARK',
#  'TORBANLEA',
#  'COOMERA',
#  'BOYNE ISLAND',
#  'CLEVELAND',
#  'BURPENGARY',
#  'CARINA HEIGHTS',
#  'WISHART',
#  'BARGARA',
#  'DRAYTON',
#  'KEDRON',
#  'CORNUBIA',
#  'ALLENSTOWN',
#  'MOOLOOLAH',
#  'REDLYNCH',
#  'ROBERTSON',
#  'DUNWICH',
#  'MARGATE',
#  'GIRU',
#  'CHARLEVILLE',
#  'PALMWOODS',
#  'URANGAN',
#  'CROWS NEST',
#  'STANTHORPE',
#  'HAMILTON',
#  'YANDINA',
#  'PADDINGTON',
#  'LITTLE MOUNTAIN',
#  'ARANA HILLS',
#  'ISLE OF CAPRI',
#  'LEICHHARDT',
#  'TALLAI',
#  'WALKERSTON',
#  'WEIPA',
#  'SINNAMON PARK',
#  'PITTSWORTH',
#  'GOOMBOORIAN',
#  'BEACONSFIELD',
#  'MOUNT OMMANEY',
#  'SIPPY DOWNS',
#  'WINTON',
#  'CLIFTON',
#  'NARANGBA',
#  'BROOKFIELD',
#  'MUNDINGBURRA',
#  'HATTON VALE',
#  'ST JOHNS WOOD',
#  'GAVEN',
#  'MIDDLE PARK',
#  'PARKINSON',
#  'MOUNT PLEASANT',
#  'BELLBOWRIE',
#  'BRINSMEAD',
#  'GLASSHOUSE MOUNTAINS',
#  'YATALA',
#  'CUNNAMULLA',
#  'INGLEWOOD',
#  'HUGHENDEN',
#  'BURBANK',
#  'AGNES WATER',
#  'BALD HILLS',
#  'HAMILTON ISLAND',
#  'HOPE ISLAND',
#  'NORTH LAKES',
#  'BARDON',
#  'MILES',
#  'MEANDARRA',
#  'TOOBEAH',
#  'TAROOM',
#  'MACLAGAN',
#  'INJUNE',
#  'SURAT',
#  'TOLGA',
#  'DEAGON',
#  'MURARRIE',
#  'NORTH TOOWOOMBA',
#  'MUNDUBBERA',
#  'LOTA',
#  'NORMAN PARK',
#  'MOUNT GRAVATT EAST',
#  'DARRA',
#  'BANYO',
#  'FRESHWATER',
#  'SUNNYBANK',
#  'CORINDA',
#  'MOUNT CROSBY',
#  'CHAPEL HILL',
#  'RAINWORTH',
#  'UPPER MOUNT GRAVATT',
#  'COOLUM',
#  'GREENSLOPES',
#  'ANNERLEY',
#  'NORTHWARD',
#  'WAVELL HEIGHTS',
#  'EASTERN HEIGHTS',
#  'FRENCHVILLE',
#  'PULLENVALE',
#  'MOUNT COTTON',
#  'CAMP HILL',
#  'PACIFIC PARADISE',
#  'SEVEN HILLS',
#  'SAMFORD',
#  'CHEVALLUM',
#  'RICHMOND',
#  'DUTTON PARK',
#  'NORTH ARM',
#  'CLEAR ISLAND WATERS',
#  'SCARBOROUGH',
#  'CARAVONICA',
#  'MACGREGOR',
#  'GRANGE',
#  'MT WARREN PARK',
#  'VIRGINIA',
#  'WOODEND',
#  'BEECHMONT',
#  'BUNDABERG NORTH',
#  'BOHLE',
#  'YORKEYS KNOB',
#  'REDLAND BAY',
#  'CHURCHILL',
#  'MUSGRAVE HILL',
#  'SHORNCLIFFE',
#  'KARRABIN',
#  'ATHERTON',
#  'KAMERUNGA',
#  'GEEBUNG',
#  'KANGAROO POINT',
#  'BLI BLI',
#  'HERMIT PARK',
#  'EAST IPSWICH',
#  'KIMBERLEY PARK',
#  'MOGGILL',
#  'MOUNT NEBO',
#  'SOUTH TOWNSVILLE',
#  'GOWRIE JUNCTION',
#  'IPSWICH',
#  'JAMBOREE HEIGHTS',
#  'KINGSTHORPE',
#  'UPPER COOMERA',
#  'SILKSTONE',
#  'MT NATHAN',
#  'BUNDABERG SOUTH',
#  'BUNDABERG WEST',
#  'MOUNT SAMSON',
#  'SHELDON',
#  'CAMIRA',
#  'GLENVIEW',
#  'GOOBURRUM',
#  'MERIDAN PLAINS',
#  'TRINITY PARK',
#  'NORTH CAIRNS',
#  'ALDERLEY',
#  'ALLORA',
#  'ASCOT',
#  'BABINDA',
#  'ST GEORGE',
#  'BAYVIEW HEIGHTS',
#  'BIGGENDEN',
#  'BLACKBUTT',
#  'TEVIOTVILLE',
#  'BUNGALOW',
#  'BROADBEACH',
#  'BUCASIA',
#  'BURKETOWN',
#  'BURNETT HEADS',
#  'ROSALIE',
#  'CALLIOPE',
#  'SCOTTVILLE',
#  'BATTERY HILL',
#  'DIRRANBANDI',
#  'EMU PARK',
#  'GAYTHORNE',
#  'ESK',
#  'GAYNDAH',
#  'HOPE VALE',
#  'GIN GIN',
#  'NEWTOWN',
#  'GREENBANK',
#  'GUNALDA',
#  'HOLLOWAYS BEACH',
#  'HOME HILL',
#  'CHILDERS',
#  'NORTH BOOVAL',
#  'JANDOWAE',
#  'KILCOY',
#  'KILKIVAN',
#  'KURANDA',
#  'LAIDLEY',
#  'LUTWYCHE',
#  'MALANDA',
#  'MILLMERRAN',
#  'MONTO',
#  'MOURILYAN',
#  'MURGON',
#  'NAPRANUM',
#  'MUDJIMBA',
#  'NUNDAH',
#  'OAKEY',
#  'PEREGIAN BEACH',
#  'MIRANI',
#  'MAPLETON',
#  'RAVENSHOE',
#  'THE RANGE',
#  'SOUTH KOLAN',
#  'CHELMER',
#  'TEXAS',
#  'TIERI',
#  'TOOGOOLAWAH',
#  'COOLANGATTA',
#  'WANDOAN',
#  'WUJAL WUJAL',
#  'YARRAMAN',
#  'YUNGABURRA',
#  'MOURA',
#  'WHITFIELD',
#  'DIMBULAH',
#  'CAMBOOYA',
#  'BOKARINA',
#  'SILKWOOD',
#  'GROVELY',
#  'HARRISTOWN',
#  'PACIFIC PINES',
#  'KILLARNEY',
#  'ORMEAU',
#  'WAMURAN',
#  'PETRIE TERRACE',
#  'BUNDABERG EAST',
#  'SPRINGFIELD LAKES',
#  'TAMBO',
#  'MOUNT SHERIDAN',
#  'RIVERSIDE GARDENS',
#  'WARNER',
#  'GRACEMERE',
#  'CARDWELL',
#  'CHINCHILLA',
#  'GLENELLA',
#  'MURRUMBA DOWNS',
#  'DAKABIN',
#  'FLINDERS VIEW',
#  'BEACHMERE',
#  'IDALIA',
#  'INNES PARK NORTH',
#  'MOUNT LOUISA',
#  'THURINGOWA CENTRAL',
#  'WONGALING BEACH',
#  'HERITAGE PARK',
#  'BRISBANE',
#  'BROOKWATER',
#  'WONDUNNA',
#  'DOUGLAS',
#  'IMBIL',
#  'BLACKS BEACH',
#  'THORNESIDE',
#  'EAST INNISFAIL',
#  'PARRAMATTA PARK',
#  'PELICAN WATERS',
#  'RURAL VIEW',
#  'KAWANA',
#  'PEREGIAN SPRINGS',
#  'BLACKSOIL',
#  'BONGAREE',
#  'ANSTEAD',
#  'COOKTOWN',
#  'SUNNYBANK HILLS',
#  nan,
#  'WAKERLEY',
#  'CASHMERE',
#  'CEDAR CREEK',
#  'ALGESTER EAST',
#  'BURANDA',
#  'WEST MACKAY',
#  'FOREST GLEN',
#  'UPPER CABOOLTURE',
#  'ONE MILE',
#  'WEST IPSWICH',
#  'FOREST HILL',
#  'MACLEAY ISLAND',
#  'URRAWEEN',
#  'DREWVALE',
#  'PEAK CROSSING',
#  'RICHLANDS',
#  'ALICE RIVER',
#  'ELI WATERS',
#  'CLIFTON BEACH',
#  'WALLANGARRA',
#  'AUGUSTINE HEIGHTS',
#  'TANAH MERAH',
#  'ELIMBAH',
#  'BURNSIDE',
#  'WONDAI',
#  'MANGO HILL',
#  'WALLOON',
#  'BEERBURRUM',
#  'WIGHTS MOUNTAIN',
#  'HEATHWOOD',
#  'BRISBANE AIRPORT',
#  'BUSHLAND BEACH',
#  'WOODHILL',
#  'COOMINYA',
#  'GRANVILLE',
#  'AVOCA',
#  'CAROLE PARK',
#  'DOONAN',
#  'WESTBROOK',
#  'STRETTON',
#  'MARIAN',
#  'SPRINGSURE',
#  'MACKENZIE',
#  'KALBAR',
#  'TAMBORINE MOUNTAIN',
#  'COOMERA EAST',
#  'WOONGOOLBA',
#  'COOYA BEACH',
#  'CLARENDON VIA LOWOOD',
#  'MINDEN',
#  'KIPPA RING',
#  'BURDELL',
#  'NARANGBA VALLEY',
#  'BEAUDESERT TOWN',
#  'ALAWA',
#  'ALICE SPRINGS',
#  'ALPURRURULAM',
#  'ALYANGULA',
#  'ANULA',
#  'NHULUNBUY',
#  'BAKEWELL',
#  'BATCHELOR',
#  'FREDS PASS',
#  'BERRY SPRINGS',
#  'BORROLOOLA',
#  'GILLEN',
#  'CASUARINA',
#  'KATHERINE EAST',
#  'KATHERINE',
#  'BRINKIN',
#  'DRIVER',
#  'DARWIN',
#  'LEANYER',
#  'WAGAMAN',
#  'GAPUWIYAK',
#  'GIRRAWEEN',
#  'BEES CREEK',
#  'BERRIMAH',
#  'MARRARA',
#  'MOULDEN',
#  'NIGHTCLIFF',
#  'STUART PARK',
#  'TIWI',
#  'GRAY',
#  'WANGURI',
#  'HOWARD SPRINGS',
#  'HUMPTY DOO',
#  'JABIRU',
#  'JINGILI',
#  'KALKARINDJI',
#  'KARAMA',
#  'KATHERINE SOUTH',
#  'LAJAMANU',
#  'LARAPINTA',
#  'LARRAKEYAH',
#  'TINDAL',
#  'SANTA TERESA',
#  'LUDMILLA',
#  'MILLNER',
#  'MALAK',
#  'MANINGRIDA',
#  'MILIKAPITI',
#  'MILINGIMBI',
#  'MINYERRI',
#  'MOIL',
#  'NGUIU',
#  'NAKARA',
#  'HERMANNSBURG',
#  'NUMBULWAR',
#  'WADEYE',
#  'PARAP',
#  'WOODROFFE',
#  'RAMINGINING',
#  'ROSEBERY',
#  'EAST SIDE',
#  'SADADEEN',
#  'GALIWINKU',
#  'TENNANT CREEK',
#  'BESWICK',
#  'WULAGI',
#  'YIRRKALA',
#  'YUENDUMU',
#  'YULARA',
#  'ALEXANDRA',
#  'ALTONA',
#  'SEAHOLME',
#  'ALTONA MEADOWS',
#  'ALTONA NORTH',
#  'NATIMUK',
#  'ARARAT',
#  'WILLAURA',
#  'EAST SALE',
#  'STRATFORD',
#  'BACCHUS MARSH',
#  'DARLEY',
#  'BAIRNSDALE',
#  'LINDENOW',
#  'PAYNESVILLE',
#  'BALLAN',
#  'BALLARAT',
#  'REDAN',
#  'BROWN HILL',
#  'BLACK HILL',
#  'WENDOUREE',
#  'ALFREDTON',
#  'INVERLEIGH',
#  'MORIAC',
#  'ANGLESEA',
#  'JAN JUC',
#  'BEECHWORTH',
#  'LEOPOLD',
#  'NEWCOMB',
#  'OCEAN GROVE',
#  'PORTARLINGTON',
#  'CLIFTON SPRINGS',
#  'WHITTINGTON',
#  'BENALLA',
#  'BENDIGO',
#  'BENDIGO SOUTH',
#  'GOLDEN SQUARE',
#  'WHITE HILLS',
#  'NARRE WARREN',
#  'BERWICK',
#  'ENDEAVOUR HILLS',
#  'HALLAM',
#  'GEMBROOK',
#  'NAR NAR GOON',
#  'PAKENHAM',
#  'BUNYIP',
#  'GARFIELD',
#  'BEACONSFIELD UPPER',
#  'COCKATOO',
#  'OFFICER',
#  'LANG LANG',
#  'BOX HILL NORTH',
#  'MONT ALBERT NORTH',
#  'BOX HILL SOUTH',
#  'BURWOOD',
#  'SURREY HILLS',
#  'BOX HILL',
#  'BRIGHTON EAST',
#  'BROADFORD',
#  'CAMPBELLFIELD',
#  'FAWKNER',
#  'OAK PARK',
#  'TULLAMARINE',
#  'WESTMEADOWS',
#  'MEADOW HEIGHTS',
#  'GLENROY',
#  'EAST BRUNSWICK',
#  'BRUNSWICK WEST',
#  'BRUNSWICK',
#  'SUNBURY',
#  'CRAIGIEBURN',
#  'GREENVALE',
#  'ROXBURGH PARK',
#  'ATTWOOD',
#  'DROUIN',
#  'LONGWARRY',
#  'BUNINYONG',
#  'MOUNT CLEAR',
#  'ASHBURTON',
#  'BALWYN',
#  'BALWYN NORTH',
#  'GLEN IRIS',
#  'CAMBERWELL',
#  'CANTERBURY',
#  'DEEPDENE',
#  'CAMPERDOWN',
#  'CASTLEMAINE',
#  'CAULFIELD SOUTH',
#  'ELSTERNWICK',
#  'ORMOND',
#  'ST KILDA EAST',
#  'MURRUMBEENA',
#  'BALACLAVA',
#  'GLEN HUNTLY',
#  'CHARLTON',
#  'ASPENDALE',
#  'EDITHVALE',
#  'CHELSEA',
#  'BONBEACH',
#  'CARRUM',
#  'COBRAM',
#  'COBURG NORTH',
#  'MERLYNSTON',
#  'PASCOE VALE',
#  'PASCOE VALE SOUTH',
#  'COBURG',
#  'MORELAND',
#  'COHUNA',
#  'LEITCHVILLE',
#  'COLAC',
#  'ELLIMINYT',
#  'COLLINGWOOD',
#  'ABBOTSFORD',
#  'CORIO',
#  'BELL POST HILL',
#  'LARA',
#  'NORLANE',
#  'BELL PARK',
#  'HAMPTON PARK',
#  'LANGWARRIN',
#  'BAYLES',
#  'KOO WEE RUP',
#  'PEARCEDALE',
#  'CRANBOURNE',
#  'CARRUM DOWNS',
#  'CRESWICK',
#  'CROYDON',
#  'CROYDON SOUTH',
#  'WARRANWOOD',
#  'CROYDON NORTH',
#  'BAYSWATER NORTH',
#  'DANDENONG',
#  'DANDENONG NORTH',
#  'DAYLESFORD',
#  'HEPBURN',
#  'TONGALA',
#  'BRIAR HILL',
#  'BUNDOORA',
#  'GREENSBOROUGH',
#  'DIAMOND CREEK',
#  'WATSONIA',
#  'ELTHAM',
#  'YARRAMBAT',
#  'ST HELENA',
#  'JEPARIT',
#  'BULLEEN',
#  'DONCASTER',
#  'DONCASTER EAST',
#  'DONVALE',
#  'PARK ORCHARDS',
#  'TEMPLESTOWE',
#  'TEMPLESTOWE LOWER',
#  'WARRANDYTE',
#  'MINYIP',
#  'MURTOA',
#  'CALIFORNIA GULLY',
#  'ECHUCA',
#  'ECHUCA SOUTH',
#  'LOWER PLENTY',
#  'MONTMORENCY SOUTH',
#  'PANTON HILL',
#  'RESEARCH',
#  'MONTMORENCY',
#  'HURSTBRIDGE',
#  'ASCOT VALE',
#  'ASCOT VALE WEST',
#  'ABERFELDIE',
#  'ESSENDON',
#  'STRATHMORE',
#  'ESSENDON NORTH',
#  'FLEMINGTON',
#  'EUROA',
#  'FITZROY NORTH',
#  'FITZROY',
#  'CARLTON NORTH',
#  'DROMANA',
#  'RYE',
#  'SORRENTO',
#  'FLINDERS',
#  'ROSEBUD',
#  'TOOTGAROOK',
#  'WEST FOOTSCRAY',
#  'YARRAVILLE',
#  'SOUTH KINGSVILLE',
#  'FOOTSCRAY',
#  'FRANKSTON SOUTH',
#  'FRANKSTON',
#  'SEAFORD',
#  'SEAFORD NORTH',
#  'MOUNT ELIZA',
#  'BREAKWATER',
#  'EAST GEELONG',
#  'GEELONG WEST',
#  'HERNE HILL',
#  'GEELONG NORTH',
#  'MACEDON',
#  'GISBORNE',
#  'BOORT',
#  'NAGAMBIE',
#  'HAWTHORN',
#  'HAWTHORN EAST',
#  'HASTINGS',
#  'CRIB POINT',
#  'BALNARRING',
#  'BAXTER',
#  'SOMERS',
#  'TYABB',
#  'SOMERVILLE',
#  'BITTERN',
#  'HEALESVILLE',
#  'YARRA GLEN',
#  'YALLAMBIE',
#  'ROSANNA',
#  'VIEWBANK',
#  'MACLEOD',
#  'IVANHOE',
#  'HEIDELBERG HEIGHTS',
#  'HEIDELBERG',
#  'COBDEN',
#  'TIMBOON',
#  'HORSHAM',
#  'ELMORE',
#  'EPSOM',
#  'HUNTLY',
#  'HOPETOUN',
#  'BEULAH',
#  'AIRPORT WEST',
#  'KEILOR',
#  'KEILOR EAST',
#  'ST ALBANS',
#  'ST ALBANS NORTH',
#  'KEILOR PARK',
#  'KINGS PARK',
#  'KEILOR DOWNS',
#  'TAYLORS LAKES',
#  'SYDENHAM',
#  'DELAHEY',
#  'KEW',
#  'KEW EAST',
#  'KEW NORTH',
#  'WALLAN',
#  'WANDONG',
#  'BORONIA',
#  'BORONIA WEST',
#  'FERNTREE GULLY',
#  'ROWVILLE',
#  'WANTIRNA SOUTH',
#  'KNOXFIELD',
#  'THE BASIN',
#  'SCORESBY',
#  'WANTIRNA',
#  'WEDDERBURN',
#  'LOCH',
#  'POOWONG',
#  'GOROKE',
#  'KYABRAM',
#  'TRENTHAM',
#  'KILSYTH',
#  'LILYDALE',
#  'MONTROSE',
#  'MOOROOLBARK',
#  'MOUNT EVELYN',
#  'WANDIN NORTH',
#  'SEVILLE',
#  'COLDSTREAM',
#  'HEYFIELD',
#  'MAFFRA',
#  'MALDON',
#  'ARMADALE',
#  'MALVERN EAST',
#  'MALVERN',
#  'KANGAROO FLAT',
#  'HEATHCOTE',
#  'CARLTON',
#  'EAST MELBOURNE',
#  'KENSINGTON',
#  'NORTH MELBOURNE',
#  'SOUTH YARRA',
#  'PARKVILLE',
#  'MELTON WEST',
#  'MELTON',
#  'DIGGERS REST',
#  'ROCKBANK',
#  'HILLSIDE',
#  'MELTON SOUTH',
#  'MILDURA',
#  'IRYMPLE',
#  'MERBEIN',
#  'RED CLIFFS',
#  'WERRIMULL',
#  'NANGILOC',
#  'MACARTHUR',
#  'NULLAWARRE',
#  ...]

# %%
edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17663 entries, 0 to 17662
# Data columns (total 22 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ServiceName                                17663 non-null  object
#  1   ProviderLegalName                          17556 non-null  object
#  2   ServiceType                                17663 non-null  object
#  3   Suburb                                     17653 non-null  object
#  4   State                                      17653 non-null  object
#  5   Postcode                                   17653 non-null  float64
#  6   NumberOfApprovedPlaces                     17246 non-null  float64
#  7   QualityArea1Rating                         16336 non-null  object
#  8   QualityArea2Rating                         16336 non-null  object
#  9   QualityArea3Rating                         16336 non-null  object
#  10  QualityArea4Rating                         16336 non-null  object
#  11  QualityArea5Rating                         16336 non-null  object
#  12  QualityArea6Rating                         16336 non-null  object
#  13  QualityArea7Rating                         16336 non-null  object
#  14  OverallRating                              16336 non-null  object
#  15  RatingsIssued                              16336 non-null  object
#  16  Long Day Care                              17663 non-null  object
#  17  Preschool/Kindergarten - Part of a School  17663 non-null  object
#  18  Preschool/Kindergarten - Stand alone       17663 non-null  object
#  19  Outside school Hours Care - After School   17663 non-null  object
#  20  Outside school Hours Care - Before School  17663 non-null  object
#  21  Outside school Hours Care - Vacation Care  17663 non-null  object
# dtypes: float64(2), object(20)
# memory usage: 3.0+ MB

# %% [markdown]
# ## Reviews (reviews)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29427 entries, 0 to 29426
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ServiceName             29427 non-null  object
#  1   TitleShownOnGoogleMaps  29427 non-null  object
#  2   overall_rating          29427 non-null  float64
#  3   5 stars                 29248 non-null  float64
#  4   4 stars                 29248 non-null  float64
#  5   3 stars                 29248 non-null  float64
#  6   2 stars                 29248 non-null  float64
#  7   1 stars                 29248 non-null  float64
#  8   individual_rating       29427 non-null  object
#  9   individual_comments     23321 non-null  object
# dtypes: float64(6), object(4)
# memory usage: 2.2+ MB

# %%
reviews.head()
# Out:
#                        ServiceName           TitleShownOnGoogleMaps  \
# 0  Chrysalis Early Learning Centre  Chrysalis Early Learning Centre
# 1  Chrysalis Early Learning Centre  Chrysalis Early Learning Centre
# 2  Chrysalis Early Learning Centre  Chrysalis Early Learning Centre
# 3  Chrysalis Early Learning Centre  Chrysalis Early Learning Centre
# 4  Chrysalis Early Learning Centre  Chrysalis Early Learning Centre
#
#    overall_rating  5 stars  4 stars  3 stars  2 stars  1 stars  \
# 0             4.8     58.0      3.0      0.0      0.0      3.0
# 1             4.8     58.0      3.0      0.0      0.0      3.0
# 2             4.8     58.0      3.0      0.0      0.0      3.0
# 3             4.8     58.0      3.0      0.0      0.0      3.0
# 4             4.8     58.0      3.0      0.0      0.0      3.0
#
#   individual_rating                                individual_comments
# 0           5 stars  Sending our daughter to Chrysalis was the best...
# 1           5 stars  Chrysalis is an incredible daycare centre for ...
# 2           5 stars  My child loves attending Chrysalis, often not ...
# 3           5 stars  I have had the pleasure of all 3 of my kids at...
# 4           5 stars  Our daughter has absolutely thrived during her...

# %%
reviews = reviews.rename(columns={'individual_comments': 'comments'})

# %%
reviews = reviews[['ServiceName', 'TitleShownOnGoogleMaps', 'overall_rating', 'comments']]
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29427 entries, 0 to 29426
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ServiceName             29427 non-null  object
#  1   TitleShownOnGoogleMaps  29427 non-null  object
#  2   overall_rating          29427 non-null  float64
#  3   comments                23321 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 919.7+ KB

# %% [markdown]
# ## SEIFA

# %%
seifa_path = pd.ExcelFile('Local Government Area, Indexes, SEIFA 2021.xlsx')
seifa_xls = pd.ExcelFile(seifa_path)
irsd_df = seifa_xls.parse('Table 2', skiprows=5)

seifa = irsd_df.iloc[:, [0, 1, 2, 3, 5]].copy()

seifa = seifa.rename(columns={
    seifa.columns[0]: 'lga_code',    # Column 0 renamed to lga_code
    seifa.columns[1]: 'Suburb',    # Column 1 renamed to lga_name
    seifa.columns[2]: 'Population',
    seifa.columns[3]: 'SEIFA_Score',
    seifa.columns[4]: 'SEIFA_Rank'
})
seifa = seifa.dropna(subset=['Population', 'SEIFA_Score'])

seifa = seifa.assign(
    **{
        'Population': seifa['Population'].astype('int'),
        'Suburb': seifa['Suburb'].str.upper(),
        'SEIFA_Score': seifa['SEIFA_Score'].round(4),
        'SEIFA_Rank': seifa['SEIFA_Rank'].astype('int'),
    }
)
seifa = seifa.reset_index(drop=True)
seifa.sample(20)
# Out:
#     lga_code               Suburb  Population  SEIFA_Score  SEIFA_Rank
# 279    37010           TOWNSVILLE      192768     989.6303         321
# 151    22410              GLENELG       20152     952.2992         170
# 14     11150               BOURKE        2340     946.6859         152
# 360    50250            ASHBURTON        7391    1023.5834         432
# 346    47910            TUMBY BAY        2817     993.4515         338
# 375    51310            CAMBRIDGE       28876    1112.5592         545
# 200    26890         WEST WIMMERA        4006     991.0073         326
# 359    50210             ARMADALE       94184     989.9997         323
# 241    33830            HOPE VALE         976     630.7883          26
# 0      10050               ALBURY       56093     967.9040         232
# 545    89399   UNINCORPORATED ACT      453890    1070.9229         514
# 508    62210          GEORGE TOWN        7033     860.4701          45
# 513    63210              KENTISH        6603     953.2327         175
# 84     15900            NEWCASTLE      168873    1012.1074         406
# 195    26610            SWAN HILL       21403     940.6168         134
# 171    24410            MAROONDAH      115043    1041.0267         474
# 39     12750          EUROBODALLA       40593     984.6770         295
# 183    25490                MOYNE       17374    1028.9786         449
# 65     14700            LANE COVE       39438    1104.9117         539
# 25     11650  CENTRAL COAST (NSW)      346596     994.1519         342

# %% [markdown]
# # Merge

# %%
df = edu.merge(reviews, on='ServiceName', how='left') \
        .merge(lga, on='Suburb', how='left') \
        .merge(aedc, on='State', how='left') \
        .merge(seifa, on=['Suburb','lga_code'], how='left')

df.sample(5)
# Out:
#                                               ServiceName  \
# 2110                             Leaps & Bounds Parklands
# 124866  Lady Gowrie - Glenorchy Outside School Hours Care
# 64083                             KU Sutherland Preschool
# 19526                             St Andrews Kindergarten
# 151289                                Braitling Preschool
#
#                                        ProviderLegalName        ServiceType  \
# 2110        Phoenix Operations Pty Ltd ATF Phoenix Trust  Centre-Based Care
# 124866                         Lady Gowrie Tasmania Inc.  Centre-Based Care
# 64083                             KU Children's Services  Centre-Based Care
# 19526   Young Mens Christian Association Of Ballarat Inc  Centre-Based Care
# 151289              Department of Education and Training  Centre-Based Care
#
#                Suburb State  Postcode  NumberOfApprovedPlaces  \
# 2110        TOOWOOMBA   QLD    4350.0                    63.0
# 124866      GLENORCHY   TAS    7010.0                    45.0
# 64083      SUTHERLAND   NSW    2232.0                    40.0
# 19526          ARARAT   VIC    3377.0                    30.0
# 151289  ALICE SPRINGS    NT     870.0                    88.0
#
#        QualityArea1Rating QualityArea2Rating QualityArea3Rating  \
# 2110          Meeting NQS        Meeting NQS        Meeting NQS
# 124866        Meeting NQS        Meeting NQS        Meeting NQS
# 64083       Exceeding NQS        Meeting NQS        Meeting NQS
# 19526         Meeting NQS        Meeting NQS        Meeting NQS
# 151289        Meeting NQS        Meeting NQS        Meeting NQS
#
#        QualityArea4Rating QualityArea5Rating QualityArea6Rating  \
# 2110          Meeting NQS        Meeting NQS        Meeting NQS
# 124866        Meeting NQS        Meeting NQS        Meeting NQS
# 64083       Exceeding NQS      Exceeding NQS      Exceeding NQS
# 19526         Meeting NQS        Meeting NQS        Meeting NQS
# 151289        Meeting NQS        Meeting NQS        Meeting NQS
#
#        QualityArea7Rating  OverallRating RatingsIssued Long Day Care  \
# 2110          Meeting NQS    Meeting NQS      Jul 2021           Yes
# 124866        Meeting NQS    Meeting NQS      Feb 2024            No
# 64083       Exceeding NQS  Exceeding NQS      Jul 2019           Yes
# 19526         Meeting NQS    Meeting NQS      Oct 2023            No
# 151289        Meeting NQS    Meeting NQS      Aug 2023            No
#
#        Preschool/Kindergarten - Part of a School  \
# 2110                                          No
# 124866                                        No
# 64083                                         No
# 19526                                         No
# 151289                                       Yes
#
#        Preschool/Kindergarten - Stand alone  \
# 2110                                    Yes
# 124866                                   No
# 64083                                   Yes
# 19526                                   Yes
# 151289                                   No
#
#        Outside school Hours Care - After School  \
# 2110                                         No
# 124866                                      Yes
# 64083                                        No
# 19526                                        No
# 151289                                       No
#
#        Outside school Hours Care - Before School  \
# 2110                                          No
# 124866                                        No
# 64083                                         No
# 19526                                         No
# 151289                                        No
#
#        Outside school Hours Care - Vacation Care TitleShownOnGoogleMaps  \
# 2110                                          No                    NaN
# 124866                                       Yes                    NaN
# 64083                                         No                    NaN
# 19526                                         No                    NaN
# 151289                                        No                    NaN
#
#         overall_rating comments lga_code     Domain LGA_Year  Domain_pct  \
# 2110               NaN      NaN    36910        DV2     2012     15.0843
# 124866             NaN      NaN    62610        DV1     2009     24.0326
# 64083              NaN      NaN      NaN        NaN      NaN         NaN
# 19526              NaN      NaN    20260     Social     2018     15.2542
# 151289             NaN      NaN    70200  Emotional     2012      8.7912
#
#         Enrollment_pct  Attendance_pct  Population  SEIFA_Score  SEIFA_Rank
# 2110           18.7145         18.9186    173204.0     979.3785       278.0
# 124866          2.2579          2.2999     50411.0     927.3687       106.0
# 64083          31.0956         31.7992         NaN          NaN         NaN
# 19526          28.7956         27.9895     11880.0     955.2148       181.0
# 151289          0.9371          0.8531     25912.0     993.9912       340.0

# %%
df['Postcode'] = df['Postcode'].astype('Int64')
df['NumberOfApprovedPlaces'] = df['NumberOfApprovedPlaces'].astype('Int64')
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 176231 entries, 0 to 196353
# Data columns (total 34 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   ServiceName                                176231 non-null  object
#  1   ProviderLegalName                          175750 non-null  object
#  2   ServiceType                                176231 non-null  object
#  3   Suburb                                     176221 non-null  object
#  4   State                                      176221 non-null  object
#  5   Postcode                                   176221 non-null  Int64
#  6   NumberOfApprovedPlaces                     174037 non-null  Int64
#  7   QualityArea1Rating                         165433 non-null  object
#  8   QualityArea2Rating                         165433 non-null  object
#  9   QualityArea3Rating                         165433 non-null  object
#  10  QualityArea4Rating                         165433 non-null  object
#  11  QualityArea5Rating                         165433 non-null  object
#  12  QualityArea6Rating                         165433 non-null  object
#  13  QualityArea7Rating                         165433 non-null  object
#  14  OverallRating                              165433 non-null  object
#  15  RatingsIssued                              165433 non-null  object
#  16  Long Day Care                              176231 non-null  object
#  17  Preschool/Kindergarten - Part of a School  176231 non-null  object
#  18  Preschool/Kindergarten - Stand alone       176231 non-null  object
#  19  Outside school Hours Care - After School   176231 non-null  object
#  20  Outside school Hours Care - Before School  176231 non-null  object
#  21  Outside school Hours Care - Vacation Care  176231 non-null  object
#  22  TitleShownOnGoogleMaps                     94226 non-null   object
#  23  overall_rating                             94226 non-null   float64
#  24  comments                                   92455 non-null   object
#  25  lga_code                                   138670 non-null  object
#  26  Domain                                     138670 non-null  object
#  27  LGA_Year                                   138670 non-null  object
#  28  Domain_pct                                 138670 non-null  float64
#  29  Enrollment_pct                             176221 non-null  float64
#  30  Attendance_pct                             176221 non-null  float64
#  31  Population                                 133140 non-null  float64
#  32  SEIFA_Score                                133140 non-null  float64
#  33  SEIFA_Rank                                 133140 non-null  float64
# dtypes: Int64(2), float64(7), object(25)
# memory usage: 47.4+ MB

# %%
df.head()
# Out:
#                                          ServiceName  \
# 0    Community Kids Waterford Early Education Centre
# 1                  KIDVENTURE EARLY LEARNING EAGLEBY
# 2                 Community Kids - Broadbeach Waters
# 3  Little Scholars School of Early Learning Burle...
# 4                     Small World Child Care Centre
#
#                                    ProviderLegalName        ServiceType  \
# 0                               G8 Education Limited  Centre-Based Care
# 1  Table Mountain Trading Pty Ltd As The Trustee ...  Centre-Based Care
# 2                               G8 Education Limited  Centre-Based Care
# 3                         The Scholars Group Pty Ltd  Centre-Based Care
# 4  A. & K. Massouras Pty. Ltd. ATF The A Massoura...  Centre-Based Care
#
#               Suburb State  Postcode  NumberOfApprovedPlaces  \
# 0     WATERFORD WEST   QLD      4133                      60
# 1            EAGLEBY   QLD      4207                      74
# 2  BROADBEACH WATERS   QLD      4217                      75
# 3    BURLEIGH WATERS   QLD      4220                     106
# 4            CARRARA   QLD      4211                      92
#
#   QualityArea1Rating QualityArea2Rating QualityArea3Rating QualityArea4Rating  \
# 0        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
# 1        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
# 2        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
# 3        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
# 4        Meeting NQS        Meeting NQS        Meeting NQS        Meeting NQS
#
#     QualityArea5Rating QualityArea6Rating QualityArea7Rating  \
# 0          Meeting NQS        Meeting NQS        Meeting NQS
# 1  Working Towards NQS        Meeting NQS        Meeting NQS
# 2          Meeting NQS        Meeting NQS        Meeting NQS
# 3          Meeting NQS        Meeting NQS        Meeting NQS
# 4          Meeting NQS        Meeting NQS        Meeting NQS
#
#          OverallRating RatingsIssued Long Day Care  \
# 0          Meeting NQS      Sep 2023           Yes
# 1  Working Towards NQS      Apr 2023           Yes
# 2          Meeting NQS      Dec 2022           Yes
# 3          Meeting NQS      Oct 2019           Yes
# 4          Meeting NQS      Jul 2023           Yes
#
#   Preschool/Kindergarten - Part of a School  \
# 0                                        No
# 1                                        No
# 2                                        No
# 3                                        No
# 4                                        No
#
#   Preschool/Kindergarten - Stand alone  \
# 0                                  Yes
# 1                                  Yes
# 2                                  Yes
# 3                                   No
# 4                                   No
#
#   Outside school Hours Care - After School  \
# 0                                       No
# 1                                      Yes
# 2                                       No
# 3                                       No
# 4                                      Yes
#
#   Outside school Hours Care - Before School  \
# 0                                        No
# 1                                       Yes
# 2                                        No
# 3                                        No
# 4                                       Yes
#
#   Outside school Hours Care - Vacation Care TitleShownOnGoogleMaps  \
# 0                                        No                    NaN
# 1                                       Yes                    NaN
# 2                                        No                    NaN
# 3                                        No                    NaN
# 4                                       Yes                    NaN
#
#    overall_rating comments lga_code Domain LGA_Year  Domain_pct  \
# 0             NaN      NaN      NaN    NaN      NaN         NaN
# 1             NaN      NaN      NaN    NaN      NaN         NaN
# 2             NaN      NaN      NaN    NaN      NaN         NaN
# 3             NaN      NaN      NaN    NaN      NaN         NaN
# 4             NaN      NaN      NaN    NaN      NaN         NaN
#
#    Enrollment_pct  Attendance_pct  Population  SEIFA_Score  SEIFA_Rank
# 0         18.7145         18.9186         NaN          NaN         NaN
# 1         18.7145         18.9186         NaN          NaN         NaN
# 2         18.7145         18.9186         NaN          NaN         NaN
# 3         18.7145         18.9186         NaN          NaN         NaN
# 4         18.7145         18.9186         NaN          NaN         NaN

# %% [markdown]
# ## Map Data

# %%
aus = gpd.read_file('32180_ERP_2024_LGA_GDA2020.gpkg')
aus.geometry = aus.geometry.simplify(0.001)
aus.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 60 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   state_code_2021                  547 non-null    int64
#  1   state_name_2021                  547 non-null    object
#  2   lga_code_2024                    547 non-null    int64
#  3   lga_name_2024                    547 non-null    object
#  4   erp_2001                         547 non-null    int64
#  5   erp_2002                         547 non-null    int64
#  6   erp_2003                         547 non-null    int64
#  7   erp_2004                         547 non-null    int64
#  8   erp_2005                         547 non-null    int64
#  9   erp_2006                         547 non-null    int64
#  10  erp_2007                         547 non-null    int64
#  11  erp_2008                         547 non-null    int64
#  12  erp_2009                         547 non-null    int64
#  13  erp_2010                         547 non-null    int64
#  14  erp_2011                         547 non-null    int64
#  15  erp_2012                         547 non-null    int64
#  16  erp_2013                         547 non-null    int64
#  17  erp_2014                         547 non-null    int64
#  18  erp_2015                         547 non-null    int64
#  19  erp_2016                         547 non-null    int64
#  20  erp_2017                         547 non-null    int64
#  21  erp_2018                         547 non-null    int64
#  22  erp_2019                         547 non-null    int64
#  23  erp_2020                         547 non-null    int64
#  24  erp_2021                         547 non-null    int64
#  25  erp_2022                         547 non-null    int64
#  26  erp_2023                         547 non-null    int64
#  27  erp_2024                         547 non-null    int64
#  28  erp_change_number_2023_24        547 non-null    int64
#  29  erp_change_per_cent_2023_24      547 non-null    float32
#  30  area_km2                         547 non-null    float64
#  31  pop_density_2024_people_per_km2  547 non-null    float64
#  32  births_2021_22                   547 non-null    int64
#  33  deaths_2021_22                   547 non-null    int64
#  34  natural_increase_2021_22         547 non-null    int64
#  35  internal_arrivals_2021_22        547 non-null    int64
#  36  internal_departures_2021_22      547 non-null    int64
#  37  net_internal_migration_2021_22   547 non-null    int64
#  38  overseas_arrivals_2021_22        547 non-null    int64
#  39  overseas_departures_2021_22      547 non-null    int64
#  40  net_overseas_migration_2021_22   547 non-null    int64
#  41  births_2022_23                   547 non-null    int64
#  42  deaths_2022_23                   547 non-null    int64
#  43  natural_increase_2022_23         547 non-null    int64
#  44  internal_arrivals_2022_23        547 non-null    int64
#  45  internal_departures_2022_23      547 non-null    int64
#  46  net_internal_migration_2022_23   547 non-null    int64
#  47  overseas_arrivals_2022_23        547 non-null    int64
#  48  overseas_departures_2022_23      547 non-null    int64
#  49  net_overseas_migration_2022_23   547 non-null    int64
#  50  births_2023_24                   547 non-null    int64
#  51  deaths_2023_24                   547 non-null    int64
#  52  natural_increase_2023_24         547 non-null    int64
#  53  internal_arrivals_2023_24        547 non-null    int64
#  54  internal_departures_2023_24      547 non-null    int64
#  55  net_internal_migration_2023_24   547 non-null    int64
#  56  overseas_arrivals_2023_24        547 non-null    int64
#  57  overseas_departures_2023_24      547 non-null    int64
#  58  net_overseas_migration_2023_24   547 non-null    int64
#  59  geometry                         547 non-null    geometry
# dtypes: float32(1), float64(2), geometry(1), int64(54), object(2)
# memory usage: 254.4+ KB

# %%
aus.head()
# Out:
#    state_code_2021  state_name_2021  lga_code_2024 lga_name_2024  erp_2001  \
# 0                1  New South Wales          10050        Albury     45265
# 1                1  New South Wales          10180      Armidale     27906
# 2                1  New South Wales          10250       Ballina     37856
# 3                1  New South Wales          10300     Balranald      2751
# 4                1  New South Wales          10470      Bathurst     35504
#
#    erp_2002  erp_2003  erp_2004  erp_2005  erp_2006  erp_2007  erp_2008  \
# 0     45816     46180     46505     47004     47566     48140     48518
# 1     27774     27610     27410     27350     27377     27468     27788
# 2     38417     38870     39120     39305     39537     39824     40020
# 3      2703      2661      2596      2545      2507      2473      2433
# 4     35831     36084     36245     36547     36916     37272     37904
#
#    erp_2009  erp_2010  erp_2011  erp_2012  erp_2013  erp_2014  erp_2015  \
# 0     48814     49222     49451     49785     50338     50990     51486
# 1     28156     28409     28573     28748     28895     29015     29160
# 2     40295     40571     40747     41118     41510     41881     42336
# 3      2404      2381      2353      2363      2381      2376      2364
# 4     38848     39484     39960     40301     40727     41157     41694
#
#    erp_2016  erp_2017  erp_2018  erp_2019  erp_2020  erp_2021  erp_2022  \
# 0     52171     53056     53922     54657     55466     56067     56665
# 1     29310     29519     29631     29701     29600     29332     29361
# 2     42993     43652     44385     44997     45663     46196     46849
# 3      2330      2338      2308      2287      2257      2208      2210
# 4     42244     42583     42882     43207     43444     43674     44110
#
#    erp_2023  erp_2024  erp_change_number_2023_24  erp_change_per_cent_2023_24  \
# 0     57509     58317                        808                       1.4050
# 1     29588     29646                         58                       0.1960
# 2     47277     47935                        658                       1.3918
# 3      2202      2219                         17                       0.7720
# 4     44606     44939                        333                       0.7465
#
#      area_km2  pop_density_2024_people_per_km2  births_2021_22  \
# 0    305.6386                         190.8038             720
# 1   7809.4406                           3.7962             336
# 2    484.9692                          98.8413             453
# 3  21690.7493                           0.1023              25
# 4   3817.8645                          11.7707             575
#
#    deaths_2021_22  natural_increase_2021_22  internal_arrivals_2021_22  \
# 0             551                       169                       4198
# 1             240                        96                       2458
# 2             491                       -38                       4084
# 3              17                         8                        196
# 4             389                       186                       3181
#
#    internal_departures_2021_22  net_internal_migration_2021_22  \
# 0                         4000                             198
# 1                         2774                            -316
# 2                         3594                             490
# 3                          210                             -14
# 4                         3074                             107
#
#    overseas_arrivals_2021_22  overseas_departures_2021_22  \
# 0                        436                          205
# 1                        467                          218
# 2                        377                          176
# 3                         13                            5
# 4                        270                          127
#
#    net_overseas_migration_2021_22  births_2022_23  deaths_2022_23  \
# 0                             231             682             527
# 1                             249             359             287
# 2                             201             424             516
# 3                               8              32              28
# 4                             143             538             359
#
#    natural_increase_2022_23  internal_arrivals_2022_23  \
# 0                       155                       3476
# 1                        72                       2090
# 2                       -92                       3058
# 3                         4                        147
# 4                       179                       2345
#
#    internal_departures_2022_23  net_internal_migration_2022_23  \
# 0                         3211                             265
# 1                         2426                            -336
# 2                         2904                             154
# 3                          175                             -28
# 4                         2279                              66
#
#    overseas_arrivals_2022_23  overseas_departures_2022_23  \
# 0                        584                          160
# 1                        663                          172
# 2                        505                          139
# 3                         22                            6
# 4                        349                           98
#
#    net_overseas_migration_2022_23  births_2023_24  deaths_2023_24  \
# 0                             424             734             485
# 1                             491             335             256
# 2                             366             400             548
# 3                              16              18              31
# 4                             251             521             408
#
#    natural_increase_2023_24  internal_arrivals_2023_24  \
# 0                       249                       3486
# 1                        79                       2017
# 2                      -148                       3316
# 3                       -13                        144
# 4                       113                       2323
#
#    internal_departures_2023_24  net_internal_migration_2023_24  \
# 0                         3260                             226
# 1                         2397                            -380
# 2                         2798                             518
# 3                          127                              17
# 4                         2310                              13
#
#    overseas_arrivals_2023_24  overseas_departures_2023_24  \
# 0                        508                          175
# 1                        545                          186
# 2                        438                          150
# 3                         19                            6
# 4                        316                          109
#
#    net_overseas_migration_2023_24  \
# 0                             333
# 1                             359
# 2                             288
# 3                              13
# 4                             207
#
#                                             geometry
# 0  POLYGON ((146.86566 -36.07292, 146.87296 -36.0...
# 1  POLYGON ((152.38816 -30.52639, 152.38742 -30.5...
# 2  MULTIPOLYGON (((153.57198 -28.87358, 153.57086...
# 3  POLYGON ((143.03952 -33.55025, 142.99242 -33.8...
# 4  POLYGON ((149.84877 -33.52784, 149.8521 -33.52...

# %%
gdf = aus.merge(df, how = 'right', left_on='lga_code_2024', right_on='lga_code')
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 176231 entries, 0 to 176230
# Data columns (total 94 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   state_code_2021                            138635 non-null  float64
#  1   state_name_2021                            138635 non-null  object
#  2   lga_code_2024                              138635 non-null  object
#  3   lga_name_2024                              138635 non-null  object
#  4   erp_2001                                   138635 non-null  float64
#  5   erp_2002                                   138635 non-null  float64
#  6   erp_2003                                   138635 non-null  float64
#  7   erp_2004                                   138635 non-null  float64
#  8   erp_2005                                   138635 non-null  float64
#  9   erp_2006                                   138635 non-null  float64
#  10  erp_2007                                   138635 non-null  float64
#  11  erp_2008                                   138635 non-null  float64
#  12  erp_2009                                   138635 non-null  float64
#  13  erp_2010                                   138635 non-null  float64
#  14  erp_2011                                   138635 non-null  float64
#  15  erp_2012                                   138635 non-null  float64
#  16  erp_2013                                   138635 non-null  float64
#  17  erp_2014                                   138635 non-null  float64
#  18  erp_2015                                   138635 non-null  float64
#  19  erp_2016                                   138635 non-null  float64
#  20  erp_2017                                   138635 non-null  float64
#  21  erp_2018                                   138635 non-null  float64
#  22  erp_2019                                   138635 non-null  float64
#  23  erp_2020                                   138635 non-null  float64
#  24  erp_2021                                   138635 non-null  float64
#  25  erp_2022                                   138635 non-null  float64
#  26  erp_2023                                   138635 non-null  float64
#  27  erp_2024                                   138635 non-null  float64
#  28  erp_change_number_2023_24                  138635 non-null  float64
#  29  erp_change_per_cent_2023_24                138635 non-null  float32
#  30  area_km2                                   138635 non-null  float64
#  31  pop_density_2024_people_per_km2            138635 non-null  float64
#  32  births_2021_22                             138635 non-null  float64
#  33  deaths_2021_22                             138635 non-null  float64
#  34  natural_increase_2021_22                   138635 non-null  float64
#  35  internal_arrivals_2021_22                  138635 non-null  float64
#  36  internal_departures_2021_22                138635 non-null  float64
#  37  net_internal_migration_2021_22             138635 non-null  float64
#  38  overseas_arrivals_2021_22                  138635 non-null  float64
#  39  overseas_departures_2021_22                138635 non-null  float64
#  40  net_overseas_migration_2021_22             138635 non-null  float64
#  41  births_2022_23                             138635 non-null  float64
#  42  deaths_2022_23                             138635 non-null  float64
#  43  natural_increase_2022_23                   138635 non-null  float64
#  44  internal_arrivals_2022_23                  138635 non-null  float64
#  45  internal_departures_2022_23                138635 non-null  float64
#  46  net_internal_migration_2022_23             138635 non-null  float64
#  47  overseas_arrivals_2022_23                  138635 non-null  float64
#  48  overseas_departures_2022_23                138635 non-null  float64
#  49  net_overseas_migration_2022_23             138635 non-null  float64
#  50  births_2023_24                             138635 non-null  float64
#  51  deaths_2023_24                             138635 non-null  float64
#  52  natural_increase_2023_24                   138635 non-null  float64
#  53  internal_arrivals_2023_24                  138635 non-null  float64
#  54  internal_departures_2023_24                138635 non-null  float64
#  55  net_internal_migration_2023_24             138635 non-null  float64
#  56  overseas_arrivals_2023_24                  138635 non-null  float64
#  57  overseas_departures_2023_24                138635 non-null  float64
#  58  net_overseas_migration_2023_24             138635 non-null  float64
#  59  geometry                                   138635 non-null  geometry
#  60  ServiceName                                176231 non-null  object
#  61  ProviderLegalName                          175750 non-null  object
#  62  ServiceType                                176231 non-null  object
#  63  Suburb                                     176221 non-null  object
#  64  State                                      176221 non-null  object
#  65  Postcode                                   176221 non-null  Int64
#  66  NumberOfApprovedPlaces                     174037 non-null  Int64
#  67  QualityArea1Rating                         165433 non-null  object
#  68  QualityArea2Rating                         165433 non-null  object
#  69  QualityArea3Rating                         165433 non-null  object
#  70  QualityArea4Rating                         165433 non-null  object
#  71  QualityArea5Rating                         165433 non-null  object
#  72  QualityArea6Rating                         165433 non-null  object
#  73  QualityArea7Rating                         165433 non-null  object
#  74  OverallRating                              165433 non-null  object
#  75  RatingsIssued                              165433 non-null  object
#  76  Long Day Care                              176231 non-null  object
#  77  Preschool/Kindergarten - Part of a School  176231 non-null  object
#  78  Preschool/Kindergarten - Stand alone       176231 non-null  object
#  79  Outside school Hours Care - After School   176231 non-null  object
#  80  Outside school Hours Care - Before School  176231 non-null  object
#  81  Outside school Hours Care - Vacation Care  176231 non-null  object
#  82  TitleShownOnGoogleMaps                     94226 non-null   object
#  83  overall_rating                             94226 non-null   float64
#  84  comments                                   92455 non-null   object
#  85  lga_code                                   138670 non-null  object
#  86  Domain                                     138670 non-null  object
#  87  LGA_Year                                   138670 non-null  object
#  88  Domain_pct                                 138670 non-null  float64
#  89  Enrollment_pct                             176221 non-null  float64
#  90  Attendance_pct                             176221 non-null  float64
#  91  Population                                 133140 non-null  float64
#  92  SEIFA_Score                                133140 non-null  float64
#  93  SEIFA_Rank                                 133140 non-null  float64
# dtypes: Int64(2), float32(1), float64(62), geometry(1), object(28)
# memory usage: 126.1+ MB

# %%
gdf = gdf.to_crs(epsg=4326)

# %% [markdown]
# # Q3
#
# ## Q3a Choropleth Map
# Which Local Government Areas (LGAs) have the highest proportions of children developmentally vulnerable in two or more domains (DV2), and how do these areas compare in terms of socio-economic disadvantage (SEIFA), remoteness, and population size?

# %%
gdf_states = gdf.dissolve(by='State').reset_index()

gdf_filtered = gdf[gdf['Domain'].isin(['DV1', 'DV2'])].copy()
state_domain_means = (
    gdf_filtered
    .groupby(['State', 'Domain'])['Domain_pct']
    .mean()
    .reset_index()
)
state_means_DV1 = state_domain_means[state_domain_means['Domain'] == 'DV1'][['State', 'Domain_pct']].rename(columns={'Domain_pct': 'DV1_pct'})
state_means_DV2 = state_domain_means[state_domain_means['Domain'] == 'DV2'][['State', 'Domain_pct']].rename(columns={'Domain_pct': 'DV2_pct'})

gdf_states = gdf_states.merge(state_means_DV1, on='State', how='left')
gdf_states = gdf_states.merge(state_means_DV2, on='State', how='left')

# %%
state_name_map = {
    'NSW': 'New South Wales',
    'VIC': 'Victoria',
    'QLD': 'Queensland',
    'SA': 'South Australia',
    'WA': 'Western Australia',
    'TAS': 'Tasmania',
    'NT': 'Northern Territory',
    'ACT': 'Australian Capital Territory'
}
state_means_DV1['state_name_2021'] = state_means_DV1['State'].map(state_name_map)
state_means_DV2['state_name_2021'] = state_means_DV2['State'].map(state_name_map)
gdf_states = aus.dissolve(by='state_name_2021').reset_index()
gdf_states = gdf_states.merge(state_means_DV1[['state_name_2021', 'DV1_pct']], on='state_name_2021', how='left')
gdf_states = gdf_states.merge(state_means_DV2[['state_name_2021', 'DV2_pct']], on='state_name_2021', how='left')

# %%
gdf_states[['state_name_2021','DV1_pct', 'DV2_pct']].round(4)
# Out:
#                 state_name_2021  DV1_pct  DV2_pct
# 0  Australian Capital Territory  22.0588  11.4560
# 1               New South Wales  19.7154   9.3757
# 2            Northern Territory  34.0356  19.8187
# 3             Other Territories      NaN      NaN
# 4                    Queensland  24.1995  13.1928
# 5               South Australia  23.4531  12.1820
# 6                      Tasmania  20.7084  10.8037
# 7                      Victoria  18.4381   9.2517
# 8             Western Australia  19.0338   8.9936

# %%
vmin_global = min(gdf_states['DV1_pct'].min(), gdf_states['DV2_pct'].min())
vmax_global = max(gdf_states['DV1_pct'].max(), gdf_states['DV2_pct'].max())

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(28, 12))

gdf_states.plot(
    column='DV1_pct',
    ax=ax1,
    legend=True,
    cmap='viridis',
    vmin=vmin_global,
    vmax=vmax_global
)
ax1.set_title('Average DV1 Percentage by State', fontsize=28, fontweight='bold', pad=20)
ax1.axis('off')

gdf_states.plot(
    column='DV2_pct',
    ax=ax2,
    legend=True,
    cmap='viridis',
    vmin=vmin_global,
    vmax=vmax_global
)
ax2.set_title('Average DV2 Percentage by State', fontsize=28, fontweight='bold', pad=20)
ax2.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q3 Distribution of Education Service and AEDC across LGAs

# %%
# Convert Quality to Numeric (1-5)：Enables the  statistical comparisons and correlation analyses with other variables such as vulnerability rates and service accessibility.
quality_map = {
      'Exceeding NQS': 5,
      'Meeting NQS': 4,
      'Working Towards NQS': 3,
      'Significant Improvement Required': 2,
      'Not Rated': 1}
df['QualityScore'] = df['OverallRating'].map(quality_map)

# %% [markdown]
# calculate the total population for each LGA (Local Government Area) and compute per capita service metrics—while avoiding double-counting population when multiple services exist in the same suburb—the following steps were taken:
#
# Remove duplicate suburb populations:
# For each suburb, only one population value is kept to prevent counting the same people multiple times.
#
# Aggregate population by LGA:
# The population of all unique suburbs within each LGA is summed to get the total LGA population.
#
# Calculate LGA-level service statistics:
# For both DV1 and DV2 domains, the code calculates the number of services, average service quality, average accessibility, and average vulnerability percentage for each LGA.
#
# Merge population data:
# The total population for each LGA is merged into the LGA service statistics table.
#
# Compute per capita metrics:
# Using the total LGA population, the code calculates the number of services and accessibility per 1,000 people, making comparisons between LGAs of different sizes fairer.

# %%
df_dv1 = df[df['Domain'] == 'DV1'].copy()
df_dv2 = df[df['Domain'] == 'DV2'].copy()

suburb_pop = df[['Suburb', 'lga_code', 'Population']].drop_duplicates(subset=['Suburb'])
lga_pop = suburb_pop.groupby('lga_code', as_index=False)['Population'].sum()

# DV1
lga_stats_dv1 = df_dv1.groupby(['State', 'lga_code']).agg(
    num_services=('ServiceName', 'nunique'),
    avg_quality=('QualityScore', 'mean'),
    avg_capacity=('NumberOfApprovedPlaces', 'mean'),
    avg_DV1_pct=('Domain_pct', 'mean')
).reset_index()

lga_stats_dv1 = lga_stats_dv1.merge(lga_pop, on='lga_code', how='left')
lga_stats_dv1['services_per_1000'] = lga_stats_dv1['num_services'] / lga_stats_dv1['Population'] * 1000
lga_stats_dv1['capacity_per_1000'] = lga_stats_dv1['avg_capacity'] / lga_stats_dv1['Population'] * 1000

# DV2
lga_stats_dv2 = df_dv2.groupby(['State', 'lga_code']).agg(
    num_services=('ServiceName', 'nunique'),
    avg_quality=('QualityScore', 'mean'),
    avg_capacity=('NumberOfApprovedPlaces', 'mean'),  #
    avg_DV2_pct=('Domain_pct', 'mean')
).reset_index()
lga_stats_dv2 = lga_stats_dv2.merge(lga_pop, on='lga_code', how='left')
lga_stats_dv2['services_per_1000'] = lga_stats_dv2['num_services'] / lga_stats_dv2['Population'] * 1000
lga_stats_dv2['capacity_per_1000'] = lga_stats_dv2['avg_capacity'] / lga_stats_dv2['Population'] * 1000

# %% [markdown]
# ## Heatmap - Correlation between Service Variables and DV1/DV2 by State
# correlation between DV1/DV2 and the three variables

# %%
states = df['State'].dropna().unique()
corrs = []

for state in states:
    sub_dv1 = lga_stats_dv1[lga_stats_dv1['State'] == state]
    sub_dv2 = lga_stats_dv2[lga_stats_dv2['State'] == state]
    corrs.append({
        'State': state,
        'DV1_num_services': sub_dv1['avg_DV1_pct'].corr(sub_dv1['num_services']),
        'DV1_quality': sub_dv1['avg_DV1_pct'].corr(sub_dv1['avg_quality']),
        'DV1_capacity': sub_dv1['avg_DV1_pct'].corr(sub_dv1['avg_capacity']),
        'DV2_num_services': sub_dv2['avg_DV2_pct'].corr(sub_dv2['num_services']),
        'DV2_quality': sub_dv2['avg_DV2_pct'].corr(sub_dv2['avg_quality']),
        'DV2_capacity': sub_dv2['avg_DV2_pct'].corr(sub_dv2['avg_capacity']),
    })

corr_df = pd.DataFrame(corrs).set_index('State')
corr_df.head()
# Out:
#        DV1_num_services  DV1_quality  DV1_capacity  DV2_num_services  \
# State
# QLD            0.075723    -0.051668      0.190512          0.004749
# NT             0.368613    -0.906421     -0.692557          0.336459
# VIC            0.105036    -0.008982      0.138977          0.120602
# NSW           -0.090965    -0.178612     -0.255449         -0.145124
# ACT           -0.661374     0.423740      0.424812         -0.676283
#
#        DV2_quality  DV2_capacity
# State
# QLD      -0.212005      0.065765
# NT       -0.899435     -0.666701
# VIC      -0.014878      0.060250
# NSW      -0.213854     -0.273740
# ACT       0.493114      0.429563

# %% [markdown]
# The correlation coefficients between AEDC outcomes (DV1 and DV2) and three education service variables (number of services, quality, and accessibility) for each state separately.

# %%
heatmap_df = corr_df.stack().unstack(0)
plt.figure(figsize=(8, 5))
sns.heatmap(heatmap_df, annot=True, cmap='vlag', center=0)
plt.title('Correlation between Service Variables and DV1/DV2 by State')
plt.ylabel('Variable')
plt.xlabel('State')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scatter Plot: LGA Service Count, Quality, and Accessibility Compared to DV1 (Small) and DV2 (Large) Vulnerability

# %%
plt.figure(figsize=(15, 4))

# 1. Number of Services
ax1 = plt.subplot(1, 3, 1)
sns.scatterplot(data=lga_stats_dv1, x='num_services', y='avg_DV1_pct', hue='State', s=20, alpha=0.6, palette='tab10', ax=ax1, legend=False)
sns.scatterplot(data=lga_stats_dv2, x='num_services', y='avg_DV2_pct', hue='State', s=80, alpha=0.6, palette='tab10', ax=ax1, legend=False)
ax1.set_title('Number of Services')
ax1.set_xlabel('Number of Services')
ax1.set_ylabel('DV1 (small) / DV2 (large)')

# 2. Quality
ax2 = plt.subplot(1, 3, 2)
sns.scatterplot(data=lga_stats_dv1, x='avg_quality', y='avg_DV1_pct', hue='State', s=20, alpha=0.6, palette='tab10', ax=ax2, legend=False)
sns.scatterplot(data=lga_stats_dv2, x='avg_quality', y='avg_DV2_pct', hue='State', s=80, alpha=0.6, palette='tab10', ax=ax2, legend=False)
ax2.set_title('Quality')
ax2.set_xlabel('Average Quality Score')
ax2.set_ylabel('')

# 3. Capacity
ax3 = plt.subplot(1, 3, 3)
sns.scatterplot(data=lga_stats_dv1, x='avg_capacity', y='avg_DV1_pct', hue='State', s=20, alpha=0.6, palette='tab10', ax=ax3, legend=False)
sc = sns.scatterplot(data=lga_stats_dv2, x='avg_capacity', y='avg_DV2_pct', hue='State', s=80, alpha=0.6, palette='tab10', ax=ax3)
ax3.set_title('Capacity')
ax3.set_xlabel('Average Capacity')
ax3.set_ylabel('')

plt.suptitle('LGA Service Count, Quality, and Capacity vs. DV1/DV2 Rates', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.tight_layout()
# Only show the legend for the last subplot
handles, labels = ax3.get_legend_handles_labels()
ax3.legend(handles, labels, bbox_to_anchor=(1, 1), loc='upper left', title='State')
plt.show()

# %% [markdown]
# # Q4
# Do LGAs with a higher percentage of education services rated as "Exceeding National Quality Standards" (NQS) show better AEDC outcomes, particularly in domains such as language and cognitive skills? What is the relationship between operational capacity (e.g., the number of children served) and developmental vulnerability indicators? What is the relationship between enrolment rates, attendance rates and developmental vulnerability indicators?

# %%
domains = ['Health','Social','Emotional','Language','Communication']
df_domains = df[
    (df['Domain'].isin(domains)) &
    (df['LGA_Year'] == '2021')
].copy()

lga_domain_scores = (
    df_domains
    .groupby(['lga_code','Domain'])['Domain_pct']
    .mean()
    .reset_index()
)
lga_domain_wide = (
    lga_domain_scores
    .pivot(index='lga_code', columns='Domain', values='Domain_pct')
    .reset_index()
    .dropna()
)

df_exceeding = df[df['QualityScore'] == 5].copy()

lga_total = (
    df
    .groupby('lga_code')
    .agg(total_services=('ServiceName','nunique'))
    .reset_index()
)
lga_exceeding = (
    df_exceeding
    .groupby('lga_code')
    .agg(exceeding_services=('ServiceName','nunique'))
    .reset_index()
)
lga_exceeding = (
    lga_total
    .merge(lga_exceeding, on='lga_code', how='left')
    .fillna({'exceeding_services': 0})
)
lga_exceeding['exceeding_pct'] = (
    lga_exceeding['exceeding_services'] /
    lga_exceeding['total_services']
)

# Merge “exceeding_pct” with 2021 AEDC domain percentages
lga_merged = lga_exceeding.merge(
    lga_domain_wide,
    on='lga_code',
    how='left'
)
lga_merged.head()
# Out:
#    lga_code  total_services  exceeding_services  exceeding_pct  Communication  \
# 0     10050              18                 3.0       0.166667         9.7072
# 1     10250               9                 7.0       0.777778         6.2189
# 2     10300               1                 0.0       0.000000        16.6667
# 3     10600               4                 1.0       0.250000         3.6036
# 4     10650               1                 0.0       0.000000         6.6667
#
#    Emotional   Health  Language   Social
# 0     9.8765  11.4022    6.3174  12.3267
# 1     8.7065   6.9652    6.7164   6.9652
# 2    17.6471  33.3333   11.7647  17.6471
# 3     7.2072  13.5135    7.2072   6.3063
# 4    14.6067  18.8889   10.0000  13.3333

# %% [markdown]
# Filters services with a QualityScore of 5 (Exceeding), counts total and Exceeding services per lga_code, computes the proportion of Exceeding services, and merges that result with lga_domain_wide by lga_code.

# %%
lga_long = lga_merged.melt(
    id_vars=['lga_code', 'exceeding_pct'],
    value_vars=domains,
    var_name='Domain',
    value_name='domain_pct'
)

plt.figure(figsize=(10, 7))
sns.scatterplot(
    data=lga_long,
    x='exceeding_pct',
    y='domain_pct',
    hue='Domain',
    palette='Set1',
    alpha=0.7
)
plt.xlabel('Proportion of Exceeding NQS Services')
plt.ylabel('Average AEDC Domain Percentage')
plt.title('Exceeding NQS Services vs. AEDC Domains by LGA')
plt.legend(title='Domain')
plt.tight_layout()
plt.show()

# %%
lga_long['exceeding_group'] = pd.cut(
    lga_long['exceeding_pct'],
    bins=4,
    labels=['Q1','Q2','Q3','Q4'],
    include_lowest=True
)
plt.figure(figsize=(12, 6))
sns.boxplot(x='exceeding_group', y='domain_pct', hue='Domain', data=lga_long)
plt.xlabel('Exceeding NQS Proportion Group')
plt.ylabel('Average AEDC Domain Percentage')
plt.title('AEDC Outcomes by Exceeding NQS Proportion Group')
plt.legend(title='Domain')
plt.show()

# %% [markdown]
# ## Q4b
# What is the relationship between operational capacity (e.g., the number of children served) and developmental vulnerability indicators?

# %%
lga_capacity = (
    df.groupby('lga_code')
    .agg(total_capacity=('NumberOfApprovedPlaces', 'sum'))
    .reset_index()
)
lga_merged = lga_capacity.merge(
    lga_domain_wide,
    on='lga_code',
    how='left'
).dropna()

# %%
domains = ['Health','Social','Emotional','Language','Communication']
lga_long = lga_merged.melt(
    id_vars=['lga_code', 'total_capacity'],
    value_vars=domains,
    var_name='Domain',
    value_name='domain_pct'
)
g = sns.lmplot(
    data=lga_long,
    x='total_capacity',
    y='domain_pct',
    col='Domain',
    scatter_kws={'alpha': 0.7, 's': 40},
    line_kws={'color': 'red', 'lw': 1.5},
    height=4,
    aspect=1
)
for i, domain in enumerate(lga_long['Domain'].unique()):
    ax = g.axes[0, i]
    sub = lga_long[lga_long['Domain'] == domain]
    r, p = pearsonr(sub['total_capacity'], sub['domain_pct'])
    star = '*' if p < 0.05 else ''
    ax.text(
        0.05, 0.95, f"r = {r:.2f}{star}\np = {p:.3f}",
        transform=ax.transAxes,
        fontsize=12,
        verticalalignment='top',
        bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", lw=1, alpha=0.7)
    )
    ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: int(x/1000)))

g.set_axis_labels("Operational Capacity (Thousand)", "Vulnerability %")
plt.suptitle("Operational Capacity vs Vulnerability by Domain", y=1.05)
plt.show()

# %% [markdown]
# ## Q4c
# What is the relationship between enrolment rates, attendance rates and developmental vulnerability indicators?

# %%
domains = ['Health','Social','Emotional','Language','Communication']
lga_long = lga_merged.melt(
    id_vars=['lga_code', 'total_capacity'],
    value_vars=domains,
    var_name='Domain',
    value_name='domain_pct'
)

g = sns.lmplot(
    data=lga_long,
    x='total_capacity',
    y='domain_pct',
    col='Domain',
    scatter_kws={'alpha': 0.7, 's': 40},
    line_kws={'color': 'red', 'lw': 1.5},
    height=4,
    aspect=1
)

for i, domain in enumerate(lga_long['Domain'].unique()):
    ax = g.axes[0, i]
    sub = lga_long[lga_long['Domain'] == domain]
    r, p = pearsonr(sub['total_capacity'], sub['domain_pct'])
    star = '*' if p < 0.05 else ''
    ax.text(
        0.95, 0.95, f"r = {r:.2f}{star}\np = {p:.3f}",
        transform=ax.transAxes,
        fontsize=12,
        verticalalignment='top',
        horizontalalignment='right',
        bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", lw=1, alpha=0.7)
    )

    ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: int(x/1000)))

g.set_axis_labels("Operational Capacity (Thousand)", "Vulnerability %")
plt.suptitle("Operational Capacity vs Vulnerability by Domain", y=1.05)
plt.show()

# %%
domains = ['Health', 'Social', 'Emotional', 'Language', 'Communication']

lga_rates = df.groupby('lga_code').agg(
    avg_enrolment=('Enrollment_pct', 'mean'),
    avg_attendance=('Attendance_pct', 'mean')
).reset_index()

lga_merged_rates = lga_rates.merge(lga_domain_wide, on='lga_code', how='left')

lga_long = lga_merged_rates.melt(
    id_vars=['lga_code', 'avg_enrolment', 'avg_attendance'],
    value_vars=domains,
    var_name='Domain',
    value_name='domain_pct'
)

g = sns.lmplot(
    data=lga_long,
    x='avg_enrolment',
    y='domain_pct',
    col='Domain',
    scatter_kws={'alpha':0.7},
    line_kws={'color':'red'},
    height=4,
    aspect=1
)

for i, domain in enumerate(lga_long['Domain'].unique()):
    ax = g.axes[0, i]
    sub = lga_long[lga_long['Domain'] == domain]
    r, p = pearsonr(sub['avg_enrolment'], sub['domain_pct'])
    star = '*' if p < 0.05 else ''
    ax.text(
        0.95, 0.95, f"r = {r:.2f}{star}\np = {p:.3f}",
        transform=ax.transAxes,
        fontsize=12,
        verticalalignment='top',
        horizontalalignment='right',
        bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", lw=1, alpha=0.7)
    )

g.set_axis_labels("Enrolment Rate", "Vulnerability %")
plt.suptitle("Enrolment Rate vs Vulnerability by Domain", y=1.05)
plt.show()

# %%
g = sns.lmplot(
    data=lga_long,
    x='avg_attendance',
    y='domain_pct',
    col='Domain',
    scatter_kws={'alpha':0.7},
    line_kws={'color':'blue'},
    height=4,
    aspect=1
)

for i, domain in enumerate(lga_long['Domain'].unique()):
    ax = g.axes[0, i]
    sub = lga_long[lga_long['Domain'] == domain]
    r, p = pearsonr(sub['avg_attendance'], sub['domain_pct'])
    star = '*' if p < 0.05 else ''
    ax.text(
        0.95, 0.95, f"r = {r:.2f}{star}\np = {p:.3f}",
        transform=ax.transAxes,
        fontsize=12,
        verticalalignment='top',
        horizontalalignment='right',
        bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", lw=1, alpha=0.7)
    )

g.set_axis_labels("Attendance Rate", "Vulnerability %")
plt.suptitle("Attendance Rate vs Vulnerability by Domain", y=1.05)
plt.show()
